# %%
#!/usr/bin/env python
import os
from witb.utils import ioutils as io
from witb.globals import DATA_DIR
import time  
import nltk
import csv
import re, string
import collections
from collections import Counter
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import datetime

# %%
stop_words = set(stopwords.words('english'))

# %%
DATA_DIR="/home/sasha/Documents/MilaPostDoc/Python/CommonCrawl"

# %%
hatecsv='wordlists/hatebase_dict.csv'

# %%
hatelist = []
with open(hatecsv, newline='') as inputfile:
    for row in csv.reader(inputfile):
        hatelist.append(row[0])
print(len(hatelist))
# Out:
# 1034

# %%
hatelist
# Out:
# ['uncivilised',
#  'gypo',
#  'gypos',
#  'cunt',
#  'cunts',
#  'peckerwood',
#  'peckerwoods',
#  'raghead',
#  'ragheads',
#  'cripple',
#  'cripples',
#  'niggur',
#  'niggurs',
#  'yellow bone',
#  'yellow bones',
#  'muzzie',
#  'muzzies',
#  'niggar',
#  'niggars',
#  'nigger',
#  'niggers',
#  'greaseball',
#  'greaseballs',
#  'white trash',
#  'white trashes',
#  'nig nog',
#  'nig nogs',
#  'faggot',
#  'faggots',
#  'cotton picker',
#  'cotton pickers',
#  'darkie',
#  'darkies',
#  'hoser',
#  'hosers',
#  'Uncle Tom',
#  'Uncle Toms',
#  'Jihadi',
#  'Jihadis',
#  'retard',
#  'retards',
#  'hillbilly',
#  'hillbillies',
#  'fag',
#  'fags',
#  'trailer trash',
#  'trailer trashes',
#  'pikey',
#  'pikies',
#  'nicca',
#  'niccas',
#  'tranny',
#  'trannies',
#  'porch monkey',
#  'porch monkies',
#  'wigger',
#  'wiggers',
#  'wetback',
#  'wetbacks',
#  'nigglet',
#  'nigglets',
#  'wigga',
#  'wiggas',
#  'dhimmi',
#  'dhimmis',
#  'honkey',
#  'honkies',
#  'eurotrash',
#  'eurotrashes',
#  'yardie',
#  'yardies',
#  'trailer park trash',
#  'trailer park trashes',
#  'niggah',
#  'niggahes',
#  'yokel',
#  'yokels',
#  'nigguh',
#  'nigguhes',
#  'camel jockey',
#  'camel jockies',
#  'honkie',
#  'honkies',
#  'niglet',
#  'niglets',
#  'gyppo',
#  'gyppos',
#  'dyke',
#  'dykes',
#  'half breed',
#  'honky',
#  'honkies',
#  'race traitor',
#  'race traitors',
#  'jiggaboo',
#  'jiggaboos',
#  'Chinaman',
#  'Chinamans',
#  'curry muncher',
#  'curry munchers',
#  'jungle bunny',
#  'jungle bunnies',
#  'coon ass',
#  'coon asses',
#  'newfie',
#  'newfies',
#  'house nigger',
#  'house niggers',
#  'limey',
#  'limies',
#  'red bone',
#  'red bones',
#  'guala',
#  'gualas',
#  'plastic paddy',
#  'plastic paddies',
#  'whigger',
#  'whiggers',
#  'jigaboo',
#  'jigaboos',
#  'nig',
#  'nigs',
#  'Zionazi',
#  'Zionazis',
#  'spear chucker',
#  'spear chuckers',
#  'niggress',
#  'niggresses',
#  'yobbo',
#  'yobbos',
#  'border jumper',
#  'border jumpers',
#  'sperg',
#  'spergs',
#  'pommy',
#  'pommies',
#  'munter',
#  'munters',
#  'tar baby',
#  'tar babies',
#  'pommie',
#  'pommies',
#  'gyp',
#  'gyps',
#  'anchor baby',
#  'anchor babies',
#  'twat',
#  'twats',
#  'border hopper',
#  'border hoppers',
#  'queer',
#  'queers',
#  'darky',
#  'darkies',
#  'ching chong',
#  'ching chongs',
#  'khazar',
#  'khazars',
#  'gippo',
#  'gippos',
#  'skanger',
#  'skangers',
#  'beaner',
#  'beaners',
#  'quadroon',
#  'quadroons',
#  'gator bait',
#  'gator baits',
#  'Cushite',
#  'Cushites',
#  'mud shark',
#  'mud sharks',
#  'cracker',
#  'crackers',
#  'dune coon',
#  'dune coons',
#  'pickaninny',
#  'pickaninnies',
#  'slant eye',
#  'slant eyes',
#  'sideways vagina',
#  'sideways vaginas',
#  'hick',
#  'hicks',
#  'camel fucker',
#  'camel fuckers',
#  'redneck',
#  'rednecks',
#  'spiv',
#  'spivs',
#  'zipperhead',
#  'zipperheads',
#  'Kushite',
#  'Kushites',
#  'Shylock',
#  'Shylocks',
#  'gook',
#  'gooks',
#  'papist',
#  'papists',
#  'hymie',
#  'hymies',
#  'wog',
#  'wogs',
#  'scally',
#  'scallies',
#  'coon',
#  'coons',
#  'whitey',
#  'whities',
#  'nigette',
#  'nigettes',
#  'paki',
#  'pakis',
#  'towel head',
#  'towel heads',
#  'Argie',
#  'Argies',
#  'wexican',
#  'wexicans',
#  'jigger',
#  'jiggers',
#  'injun',
#  'injuns',
#  'ocker',
#  'ockers',
#  'polack',
#  'polacks',
#  'moulie',
#  'moulies',
#  'niggor',
#  'niggors',
#  'scanger',
#  'scangers',
#  'ofay',
#  'ofaies',
#  'jigga',
#  'jiggas',
#  'redskin',
#  'redskins',
#  'chonky',
#  'chonkies',
#  'hebro',
#  'hebros',
#  'wop',
#  'wops',
#  'chink',
#  'chinks',
#  'sideways pussy',
#  'sideways pussies',
#  'paleface',
#  'palefaces',
#  'wagon burner',
#  'wagon burners',
#  'nigra',
#  'nigras',
#  'spic',
#  'spics',
#  'spics',
#  'jocky',
#  'jockies',
#  'kraut',
#  'krauts',
#  'steek',
#  'steeks',
#  'coolie',
#  'coolies',
#  'gooky',
#  'gookies',
#  'octaroon',
#  'octaroons',
#  'bint',
#  'bints',
#  'shit heel',
#  'shit heels',
#  'squaw',
#  'squaws',
#  'bog trotter',
#  'bog trotters',
#  'Oriental',
#  'Orientals',
#  'halfrican',
#  'halfricans',
#  'paddy',
#  'paddies',
#  'groid',
#  'groids',
#  'jiggabo',
#  'jiggabos',
#  'jigg',
#  'jiggs',
#  'jant',
#  'jants',
#  'spide',
#  'spides',
#  'camel humper',
#  'camel humpers',
#  'white nigger',
#  'white niggers',
#  'ZOG',
#  'ZOGs',
#  'diaper head',
#  'diaper heads',
#  'heeb',
#  'heebs',
#  'Christ killer',
#  'Christ killers',
#  'piker',
#  'pikers',
#  'higger',
#  'higgers',
#  'lemonhead',
#  'lemonheads',
#  'Hun',
#  'Huns',
#  'popolo',
#  'popolos',
#  'cowboy killer',
#  'cowboy killers',
#  'jhant',
#  'jhants',
#  'eyetie',
#  'eyeties',
#  'mockey',
#  'mockies',
#  'alligator bait',
#  'alligator baits',
#  'Jap',
#  'Japs',
#  'shanty Irish',
#  'shanty Irishes',
#  'redlegs',
#  'mulignan',
#  'mulignans',
#  'jockie',
#  'jockies',
#  'mangia cake',
#  'mangia cakes',
#  'moulinyan',
#  'moulinyans',
#  'nigar',
#  'nigars',
#  'darkey',
#  'darkies',
#  'gurrier',
#  'gurriers',
#  'lubra',
#  'lubras',
#  'Buckwheat',
#  'Buckwheats',
#  'mulato',
#  'mulatos',
#  'prairie nigger',
#  'prairie niggers',
#  'kyke',
#  'kykes',
#  'boonie',
#  'boonies',
#  'mick',
#  'micks',
#  'bluegum',
#  'bluegums',
#  'spigger',
#  'spiggers',
#  'border bunny',
#  'border bunnies',
#  'kike',
#  'kikes',
#  'moulignon',
#  'moulignons',
#  'roundeye',
#  'roundeyes',
#  'ginzo',
#  'ginzos',
#  'Jewbacca',
#  'Jewbaccas',
#  'booner',
#  'booners',
#  'nigre',
#  'nigres',
#  'scallie',
#  'scallies',
#  'niger',
#  'nigers',
#  'dinge',
#  'dinges',
#  'Leb',
#  'Lebs',
#  'Lebbo',
#  'Lebbos',
#  'sambo',
#  'sambos',
#  'Africoon',
#  'Africoons',
#  'ling ling',
#  'ling lings',
#  'gub',
#  'gubs',
#  'banana bender',
#  'banana benders',
#  'japie',
#  'japies',
#  'island nigger',
#  'island niggers',
#  'hairyback',
#  'hairybacks',
#  'lugan',
#  'lugans',
#  'Bog Irish',
#  'Bog Irishes',
#  'blaxican',
#  'blaxicans',
#  'moke',
#  'mokes',
#  'nigor',
#  'nigors',
#  'bix nood',
#  'bix noods',
#  'Kushi',
#  'Kushis',
#  'guala guala',
#  'guala gualas',
#  'hoosier',
#  'hoosiers',
#  'thicklips',
#  'mook',
#  'mooks',
#  'muk',
#  'muks',
#  'soup taker',
#  'soup takers',
#  'senga',
#  'sengas',
#  'Cushi',
#  'Cushis',
#  'pogue',
#  'pogues',
#  'abo',
#  'abos',
#  'ping pang',
#  'ping pangs',
#  'proddy dog',
#  'proddy dogs',
#  'boong',
#  'boongs',
#  'dago',
#  'dagos',
#  'dogun',
#  'doguns',
#  'mocky',
#  'mockies',
#  'poppadom',
#  'poppadoms',
#  'Gwat',
#  'Gwats',
#  'ice nigger',
#  'ice niggers',
#  'spook',
#  'spooks',
#  'Afro-Saxon',
#  'Afro-Saxons',
#  'guido',
#  'guidos',
#  'latrino',
#  'latrinos',
#  'lowlander',
#  'lowlanders',
#  'mockie',
#  'mockies',
#  'moky',
#  'mokies',
#  'mosshead',
#  'mossheads',
#  'African catfish',
#  'African catfishes',
#  'gyppy',
#  'gyppies',
#  'timber nigger',
#  'timber niggers',
#  'Americoon',
#  'Americoons',
#  'camel cowboy',
#  'camel cowboies',
#  'eh hole',
#  'eh holes',
#  'Hunyak',
#  'Hunyaks',
#  'slopehead',
#  'slopeheads',
#  'teabagger',
#  'teabaggers',
#  'Armo',
#  'Armos',
#  'bitch',
#  'bitches',
#  'greaser',
#  'greasers',
#  'Honyock',
#  'Honyocks',
#  'mud person',
#  'mud persons',
#  'pineapple nigger',
#  'pineapple niggers',
#  'retarded',
#  'semihole',
#  'semiholes',
#  'Amo',
#  'Amos',
#  'border nigger',
#  'border niggers',
#  'buckra',
#  'buckras',
#  'burrhead',
#  'burrheads',
#  'cab nigger',
#  'cab niggers',
#  'carpet pilot',
#  'carpet pilots',
#  'pancake face',
#  'pancake faces',
#  'spigotty',
#  'spigotties',
#  'carrot snapper',
#  'carrot snappers',
#  'chili shitter',
#  'chili shitters',
#  'curry slurper',
#  'curry slurpers',
#  'ghetto hamster',
#  'ghetto hamsters',
#  'ice monkey',
#  'ice monkies',
#  'roofucker',
#  'roofuckers',
#  'Velcro head',
#  'Velcro heads',
#  'wiggerette',
#  'wiggerettes',
#  'beach nigger',
#  'beach niggers',
#  'bean dipper',
#  'bean dippers',
#  'bog hopper',
#  'bog hoppers',
#  'Buddhahead',
#  'Buddhaheads',
#  'camel jacker',
#  'camel jackers',
#  'Caublasian',
#  'Caublasians',
#  'cave nigger',
#  'cave niggers',
#  'cow kisser',
#  'cow kissers',
#  'dune nigger',
#  'dune niggers',
#  'four by two',
#  'four by twos',
#  'fresh off the boat',
#  'fresh off the boats',
#  'gin jockey',
#  'gin jockies',
#  'golliwog',
#  'golliwogs',
#  'guinea',
#  'guineas',
#  'Jim Fish',
#  'Jim Fishes',
#  'mackerel snapper',
#  'mackerel snappers',
#  'octroon',
#  'octroons',
#  'pohm',
#  'pohms',
#  'pussy',
#  'pussies',
#  'Russellite',
#  'Russellites',
#  'spice nigger',
#  'spice niggers',
#  'uncivilized',
#  'Whipped',
#  'albino',
#  'albinos',
#  'ape',
#  'apes',
#  'Aunt Jemima',
#  'Aunt Jemimas',
#  'buckethead',
#  'bucketheads',
#  'Chinese wetback',
#  'Chinese wetbacks',
#  'chug',
#  'chugs',
#  'curry stinker',
#  'curry stinkers',
#  'dyke jumper',
#  'dyke jumpers',
#  'eight ball',
#  'eight balls',
#  'gun burglar',
#  'gun burglars',
#  'ikey mo',
#  'ikey mos',
#  'lawn jockey',
#  'lawn jockies',
#  'leprechaun',
#  'leprechauns',
#  'mutt',
#  'mutts',
#  'negro',
#  'negros',
#  '‘negroes’',
#  'nitchee',
#  'nitchees',
#  'sooty',
#  'sooties',
#  'spick',
#  'spicks',
#  'tinkard',
#  'tinkards',
#  'uncircumcised baboon',
#  'uncircumcised baboons',
#  'zigabo',
#  'zigabos',
#  'abbo',
#  'abbos',
#  'Anglo',
#  'Anglos',
#  'Aunt Jane',
#  'Aunt Janes',
#  'Aunt Mary',
#  'Aunt Maries',
#  'Aunt Sally',
#  'Aunt Sallies',
#  'azn',
#  'azns',
#  'bamboo coon',
#  'bamboo coons',
#  'banana lander',
#  'banana landers',
#  'banjo lips',
#  'bans and cans',
#  'beaner shnitzel',
#  'beaner shnitzels',
#  'beaney',
#  'beanies',
#  'Bengali',
#  'Bengalis',
#  'bhrempti',
#  'bhremptis',
#  'bird',
#  'birds',
#  'bitter clinger',
#  'bitter clingers',
#  'black Barbie',
#  'black Barbies',
#  'black dago',
#  'black dagos',
#  'blockhead',
#  'blockheads',
#  'bog jumper',
#  'bog jumpers',
#  'boon',
#  'boons',
#  'boonga',
#  'boongas',
#  'Bounty bar',
#  'Bounty bars',
#  'boxhead',
#  'boxheads',
#  'brass ankle',
#  'brass ankles',
#  'brownie',
#  'brownies',
#  'buffie',
#  'buffies',
#  'bug eater',
#  'bug eaters',
#  'buk buk',
#  'buk buks',
#  'bumblebee',
#  'bumblebees',
#  'bung',
#  'bungs',
#  'bunga',
#  'bungas',
#  'butterhead',
#  'butterheads',
#  'can eater',
#  'can eaters',
#  'celestial',
#  'celestials',
#  'Charlie',
#  'Charlies',
#  'chee chee',
#  'chee chees',
#  'chi chi',
#  'chi chis',
#  'chigger',
#  'chiggers',
#  'chinig',
#  'chinigs',
#  'chink a billy',
#  'chink a billies',
#  'chunky',
#  'chunkies',
#  'clam',
#  'clams',
#  'clamhead',
#  'clamheads',
#  'colored',
#  'coloured',
#  'crow',
#  'crows',
#  'dego',
#  'degos',
#  'dink',
#  'dinks',
#  'dogan',
#  'dogans',
#  'domes',
#  'dot head',
#  'dot heads',
#  'eggplant',
#  'eggplants',
#  'Fairy',
#  'Fairies',
#  'fez',
#  'fezs',
#  'FOB',
#  'FOBs',
#  'fog nigger',
#  'fog niggers',
#  'fuzzy',
#  'fuzzies',
#  'fuzzy wuzzy',
#  'fuzzy wuzzies',
#  'gable',
#  'gables',
#  'Gerudo',
#  'Gerudos',
#  'gew',
#  'gews',
#  'ghetto',
#  'ghettos',
#  'gipp',
#  'gipps',
#  'gook eye',
#  'gook eyes',
#  'gyppie',
#  'gyppies',
#  'heinie',
#  'heinies',
#  'ho',
#  'hos',
#  'hoe',
#  'hoes',
#  'Honyak',
#  'Honyaks',
#  'Hunkie',
#  'Hunkies',
#  'Hunky',
#  'Hunkies',
#  'Hunyock',
#  'Hunyocks',
#  'ike',
#  'ikes',
#  'ikey',
#  'ikies',
#  'iky',
#  'ikies',
#  'jig',
#  'jigs',
#  'jigarooni',
#  'jigaroonis',
#  'jijjiboo',
#  'jijjiboos',
#  'kotiya',
#  'kotiyas',
#  'mickey',
#  'mickies',
#  'moch',
#  'moches',
#  'mock',
#  'mocks',
#  'mong',
#  'mongs',
#  'monkey',
#  'monkies',
#  'Moor',
#  'Moors',
#  'moss eater',
#  'moss eaters',
#  'moxy',
#  'moxies',
#  'muktuk',
#  'muktuks',
#  'mung',
#  'mungs',
#  'munt',
#  'munts',
#  'ned',
#  'net head',
#  'net heads',
#  'nichi',
#  'nichis',
#  'nichiwa',
#  'nichiwas',
#  'nidge',
#  'nidges',
#  'nip',
#  'nips',
#  'nitchie',
#  'nitchies',
#  'nitchy',
#  'nitchies',
#  'Orangie',
#  'Orangies',
#  'Oreo',
#  'Oreos',
#  'papoose',
#  'papooses',
#  'piky',
#  'pikies',
#  'pinto',
#  'pintos',
#  'pointy head',
#  'pointy heads',
#  'pollo',
#  'pollos',
#  'pom',
#  'poms',
#  'pommie grant',
#  'pommie grants',
#  'Punjab',
#  'Punjabs',
#  'rube',
#  'rubes',
#  'sawney',
#  'sawnies',
#  'scag',
#  'scags',
#  'seppo',
#  'seppos',
#  'septic',
#  'septics',
#  'shant',
#  'shants',
#  'sheeny',
#  'sheenies',
#  'sheepfucker',
#  'sheepfuckers',
#  'Shelta',
#  'Sheltas',
#  'shiner',
#  'shiners',
#  'shit kicker',
#  'shit kickers',
#  'Shy',
#  'Shies',
#  'sideways cooter',
#  'sideways cooters',
#  'skag',
#  'skags',
#  'Skippy',
#  'Skippies',
#  'slag',
#  'slags',
#  'slant',
#  'slants',
#  'slit',
#  'slits',
#  'slope',
#  'slopes',
#  'slopey',
#  'slopies',
#  'slopy',
#  'slopies',
#  'smoke jumper',
#  'smoke jumpers',
#  'smoked Irish',
#  'smoked Irishes',
#  'smoked Irishman',
#  'smoked Irishmans',
#  'sole',
#  'soles',
#  'spickaboo',
#  'spickaboos',
#  'spig',
#  'spigs',
#  'spik',
#  'spiks',
#  'spink',
#  'spinks',
#  'squarehead',
#  'squareheads',
#  'squinty',
#  'squinties',
#  'stovepipe',
#  'stovepipes',
#  'sub human',
#  'sub humans',
#  'sucker fish',
#  'sucker fishes',
#  'Taffy',
#  'Taffies',
#  'teapot',
#  'teapots',
#  'tenker',
#  'tenkers',
#  'tincker',
#  'tinckers',
#  'tinkar',
#  'tinkars',
#  'tinker',
#  'tinkers',
#  'tinkere',
#  'tinkeres',
#  'trash',
#  'trashes',
#  'tree jumper',
#  'tree jumpers',
#  'tunnel digger',
#  'tunnel diggers',
#  'Twinkie',
#  'Twinkies',
#  'tyncar',
#  'tyncars',
#  'tynekere',
#  'tynekeres',
#  'tynkard',
#  'tynkards',
#  'tynkare',
#  'tynkares',
#  'tynker',
#  'tynkers',
#  'tynkere',
#  'tynkeres',
#  'WASP',
#  'WASPs',
#  'Yank',
#  'Yanks',
#  'Yankee',
#  'Yankees',
#  'yellow',
#  'yellows',
#  'yid',
#  'yids',
#  'yob',
#  'yobs',
#  'zebra',
#  'zebras',
#  'zippohead',
#  'zippoheads',
#  'ZOG lover',
#  'ZOG lovers’',
#  'knacker',
#  'knackers',
#  'shyster',
#  'shysters',
#  'bogan',
#  'bogans',
#  'hayseed',
#  'moon cricket',
#  'moon crickets',
#  'mud duck',
#  'mud ducks',
#  'surrender monkey',
#  'surrender monkies',
#  'bludger',
#  'bludgers',
#  'charver',
#  'charvers',
#  'dole bludger',
#  'dole bludgers',
#  'chav',
#  'chavs',
#  'sheister',
#  'sheisters',
#  'charva',
#  'charvas',
#  'touch of the tar brush',
#  'touch of the tar brushes',
#  'Northern monkey',
#  'Northern monkies',
#  'Southern fairy',
#  'Southern fairies',
#  'gubba',
#  'gubbas',
#  'stump jumper',
#  'stump jumpers',
#  'hebe',
#  'hebes',
#  'millie',
#  'millies',
#  'quashie',
#  'quashies',
#  'dingo fucker',
#  'dingo fuckers',
#  ...]

# %%
filenames = os.listdir(DATA_DIR)
filename = os.path.join(DATA_DIR, filenames[0])

data = io.get_entries(io.read_wet_file(filename))
parsed_data = io.parse_data(data)  # Generator.

docs = []
start_time = time.time()
for doc in parsed_data:
    docs.append(doc)

# %%
for doc in docs:
    if doc.url=='www.twinkpornvideo.com':
        testdoc=doc.content

# %%
testdoc
# Out:
# "View Park-Windsor Hills ts hookers, hook up - Twink Porn ✔️\nTWINK PORN\nHookers\nUnited States\nCalifornia\nView Park-Windsor Hills\nTs hookers View Park-Windsor Hills\nAmanda carey trans 22x4 passing through View Park-Windsor Hills 15 th for curious straight men\nTs hook up View Park-Windsor Hills\nHello everyone, I am Amanda Carey Brazilian from passag in View Park-Windsor Hills 15 EME I am active and passive. Call me for more information thanks to all of you kisses.\nParty duo your best option to make a rich trio\nView Park-Windsor Hills escort incall\nOnly a couple of scorts a beautiful girl trans gifted i morbid i a handsome guy very gifted we are very party we like the morbid and much sex we are dominant i very affectionate at the time\nKaren trans 20 cm 100% real\nView Park-Windsor Hills ts hook up\nHello darling, 200% real and NO SURPRISES ON PLACE I'm Karen, Pretty new latina in the corner. I offer you to spend divine moments with me, I am expert and gentle for beginners and I love new experiences. I like to have a good and charming time without hurry, we will take the time we need for fun. I have no taboo, wild with demanding people. What are you waiting for? Call me!\nArianna news in View Park-Windsor Hills arrives from Brazil\nTs View Park-Windsor Hills incalls escort\nHello .. I'm Arianna, a beautiful transsexual 22 years old with a beautiful surprise of 20cm, blond hair, always in a good mood smiling and elegant cultivated open cultured I offer you beautiful moments of pleasant and warm company! I am waiting for you! Thank you for making an appointment in advance! I am very feminine and very sexy Size: a physical sculpted in the gym, XL buttocks, 170 cm high, 65 kg 44 bust and 20cm of great pleasure! I love lingerie and femininity! Details about my services are available in simple call\nMilf nymphomaniac sex specialist\nHookers View Park-Windsor Hills\nBeautiful MILF nympho trans, sexy and naughty with everything you are looking for. Complete, I make your fantasies come true or I'll be your girlfriend, how can I devour you with a lot of desire, kiss your mouth with my hot and wet mouth and a greedy tongue. Come and meet me, let's enjoy unique moments! I am complete and full of desire of refined and tasteful men. I also accept couples. My location is discreet, comfortable and safe. Call 20 minutes before our meeting, we will live unforgettable moments! Kisses, Monique Mon\nTrans laura mariane passage to View Park-Windsor Hills\nProstitutes View Park-Windsor Hills\nLAURA TRANS SUPER ACTV BM/ TS 22X5 ***100% REAL PICTURES*** ⭐DISPONIBLE FROM 10:00 AM IN THE MORNING 10:00 PM *** ⭐RENDEZ YOU 30 MIN BEFORE *** Hi everyone, I'm going to introduce myself to you. My name is LAURA, I'm a beautiful Brazilian transgender, 22 years old. 1,78m 66kg. With a SURPRISE of 22x5 c m R E L for you, and B E A U C O U P - D E - S P E R M E . Sexy, soft, refined and sublime. I LOVE BEGINNERS! I propose you a meeting like no one has ever proposed you before. My delicacy is my main strong point. My photos are 100% real I offer you a quality service, discreet and confidential... I receive you in a very nice apartment, central, neat, pleasant, discreet and well decorated. All right, guys, I hope you know a little more about me and invite a meeting because we still have a lot to get to know each other. (I don't answer hidden calls) Kisses LAURA MARIANE\nMariana trans\nView Park-Windsor Hills outcalls escort\nBeautiful mariana to you. I am very well known in all the safe, feminine and sweet way. If you are looking for something really special and a little different, a little adventure to help you forget your daily worries and the stress of living, then I am here for you. Discreet, elegant. I am a classy and beautiful transsexual. I am sensitive and really interested and give you the best.\nBeautiful sexy trans métisse crossing over\nTs escort girl View Park-Windsor Hills\nHi, I'm Lola a Pretty Hot New Trans Coquine here.I like Tenderness, S ...

# %%
#Simple word search
start = time.time()
pornsites={}
for doc in docs:
    pwds=len([w for w in word_tokenize(doc.content) if w in hatelist])
    pornsites[doc.url]=pwds
duration=str(datetime.timedelta(seconds=time.time() - start))
print("Number of pages counted: ", len(pornsites))
print("Duration: ", duration)
# Out:
# Number of pages counted:  12903
# Duration:  0:07:32.756603

# %%
#Bigram search with counts
stop_words = set(stopwords.words('english'))  
start = time.time()
pornsites={}
for doc in docs:
    clean = [w.strip(string.digits + string.punctuation).lower() for w in word_tokenize(doc.content) if w not in stop_words]
    bigrams=[b for b in nltk.bigrams(word_tokenize(str(' '.join(clean))))]
    match = set(bigrams).intersection(bigramlist)
    pornsites[doc.url]=len(match)
duration=str(datetime.timedelta(seconds=time.time() - start))
print("Number of pages counted: ", len(pornsites))
print("Duration: ", duration)
# Out:
# Number of pages counted:  16354
# Duration:  0:01:44.870245

# %%
#Bigram search with counts for clean text
stop_words = set(stopwords.words('english'))  
start = time.time()
pornsites={}
for doc in docs:
    clean = [w.strip(string.digits + string.punctuation).lower() for w in word_tokenize(doc['raw_content']) if w not in stop_words]
    bigrams=[b for b in nltk.bigrams(word_tokenize(str(' '.join(clean))))]
    match = set(bigrams).intersection(bigramlist)
    pornsites[doc['url']]=len(match)
duration=str(datetime.timedelta(seconds=time.time() - start))
print("Number of pages counted: ", len(pornsites))
print("Duration: ", duration)

# %%
#Bigram search with counts and list of tuples found (for debugging)
stop_words = set(stopwords.words('english'))  
start = time.time()
pornsites={}
for doc in docs:
    clean = [w.strip(string.digits + string.punctuation).lower() for w in word_tokenize(doc.content) if w not in stop_words]
    bigrams=[b for b in nltk.bigrams(word_tokenize(str(' '.join(clean))))]
    match = set(bigrams).intersection(bigramlist)
    pornsites[doc.url]=[len(match), str(match)]
duration=str(datetime.timedelta(seconds=time.time() - start))
print("Number of pages counted: ", len(pornsites))
print("Duration: ", duration)
# Out:
# Number of pages counted:  12903
# Duration:  0:04:31.414725

# %%
{k: v for k, v in sorted(pornsites.items(), key=lambda item: item[1], reverse=True)}
# Out:
# {'adultinternetusers.com': 139,
#  'lolcow.farm': 64,
#  'hsquizbowl.org': 42,
#  'www.pspbugs.com': 35,
#  'www.fotokrystek.pl': 32,
#  'www.lindenfields.com': 32,
#  'www.topjerseysus.ru': 27,
#  'darlenedeluca.com': 26,
#  'www.bravohairy.com': 26,
#  'blog.hiddenharmonies.org': 24,
#  'board.shearwatermusic.com': 22,
#  'jyards.com': 22,
#  'taylorholmes.com': 22,
#  'www.clintonsretail.com': 22,
#  'berwickshire-placenames.glasgow.ac.uk': 21,
#  'www.theholisticentre.uk': 20,
#  'www.pornhavana.com': 19,
#  'acookingdayinrome.com': 19,
#  'fasab.wordpress.com': 19,
#  'keeprecipes.com': 19,
#  'www.mommakatandherbearcat.com': 19,
#  'www.ukdogging.co': 18,
#  'www.withalexofficialblog.com': 17,
#  'pages.sachachua.com': 16,
#  'samanthasung.com': 16,
#  'thefrugalcrafter.wordpress.com': 16,
#  'hoaxteadresearch.wordpress.com': 15,
#  'www.careerjet.com.pk': 15,
#  'www.theflatearthsociety.org': 15,
#  'somethingovertea.wordpress.com': 14,
#  'www.mrfood.com': 14,
#  'www.khalsacollege.in': 13,
#  'www.trimbosphotography.com': 13,
#  'altayer-travel.com': 13,
#  'elkriversoapcompany.com': 12,
#  'graduateland.com': 12,
#  'leica-nature-blog.com': 12,
#  'shannonsdreams.wordpress.com': 12,
#  'www.moonofalabama.org': 12,
#  'www.zomerbloemennet.nl': 12,
#  'yourbunny.mobi': 12,
#  'www.xn--80aafblbgpxxcgbigyfoeei.xn--p1ai': 11,
#  'ebonyporn.site': 11,
#  'teenpussysex.net': 11,
#  'thebloggess.com': 11,
#  'www.fapmovs.tv': 11,
#  'xcafe.com': 11,
#  'www.lonestarmusic.com': 10,
#  'afiporn.net': 10,
#  'kuenselonline.com': 10,
#  'tubenza.mobi': 10,
#  'www.crazydaysandnights.net': 10,
#  'www.frugalwoods.com': 10,
#  'www.fs.usda.gov': 10,
#  'www.seattletimes.com': 10,
#  'www.somanyrecordssolittletime.com': 9,
#  'www.unlikely-story.com': 9,
#  'consultingbyrpm.com': 9,
#  'fantageville.wordpress.com': 9,
#  'jornada.nmsu.edu': 9,
#  'paularenee.wordpress.com': 9,
#  'penisextendersonreview.com': 9,
#  'traveljourneysofalifetime.com': 9,
#  'www.karrinyupcentre.com.au': 9,
#  'www.myguidealicante.com': 9,
#  'www.needlenthread.com': 9,
#  'insecure.archiveofourown.org': 8,
#  't-central.blogspot.com': 8,
#  'www.soundimage.eu': 8,
#  'ericflint.net': 8,
#  'halfchinese.org': 8,
#  'hull-repository.worktribe.com': 8,
#  'miraclesteam.com': 8,
#  'newyork.cbslocal.com': 8,
#  'secretartexpedition.wordpress.com': 8,
#  'snowflow.com.au': 8,
#  'teawithgary.com': 8,
#  'www.ambiance-sticker.com': 8,
#  'www.edwardgreen.com': 8,
#  'www.erieville.com': 8,
#  'www.lifeexperiences.ca': 8,
#  'www.printtee.net': 8,
#  'www.techgalatta.xyz': 8,
#  'hoetoob.com': 7,
#  'www.cloverfieldnews.com': 7,
#  '1d4chan.org': 7,
#  'fanfaps.com': 7,
#  'keralasdotlive.wordpress.com': 7,
#  'magicfairycandles.com': 7,
#  'soundstudiesblog.com': 7,
#  'survivalsherpa.wordpress.com': 7,
#  'windypinwheel.com': 7,
#  'www.mothering.com': 7,
#  'www.nkytribune.com': 7,
#  'www.thesoleline.com': 7,
#  'yourhomeonlybetter.com': 7,
#  'yourlifeasartessentials.com': 7,
#  'henryhemming.com': 6,
#  'suimazate1989.no.comunidades.net': 6,
#  'thingsasian.com': 6,
#  'waysofknowing.kira.org': 6,
#  'www.deckert.org': 6,
#  'www.krapsody.com': 6,
#  'www.momtubexxx.com': 6,
#  'casualsexproject.com': 6,
#  'coastmonkey.ie': 6,
#  'diablotube.mobi': 6,
#  'freedomborn.wordpress.com': 6,
#  'freesex24.pro': 6,
#  'johnelite.com': 6,
#  'latinoheritageintern.com': 6,
#  'madeduck.com': 6,
#  'momsuckxxx.com': 6,
#  'pornoteen.me': 6,
#  'queerimpressions.wordpress.com': 6,
#  'remodernreview.wordpress.com': 6,
#  'thetinypinkclover.wordpress.com': 6,
#  'www.86avenue.ch': 6,
#  'www.cherry-lane.co.uk': 6,
#  'www.instructables.com': 6,
#  'www.outokumpu.com': 6,
#  'www.savvydistro.co.uk': 6,
#  'www.woodyboater.com': 6,
#  'henriettacreekorchard.com': 5,
#  'lip2014.eu': 5,
#  'pueyandtheprincess.conlang.org': 5,
#  'sergesblog.blogspot.com': 5,
#  'taga-ilog-news.blogspot.com': 5,
#  'www.abcd-diaries.com': 5,
#  'www.japancarpages.com': 5,
#  'www.nepsacbasketball.org': 5,
#  'www.sunilrajguru.com': 5,
#  'agodeu.com': 5,
#  'candcindia.com': 5,
#  'crosswordfiend.com': 5,
#  'dailylivingministries.wordpress.com': 5,
#  'forgotyourcommonsense.com': 5,
#  'forum.bandmix.com': 5,
#  'garbags.com': 5,
#  'growingfamily.co.uk': 5,
#  'meandrichard.wordpress.com': 5,
#  'metrosource.com': 5,
#  'originalhindiporn.mobi': 5,
#  'pornokim.com': 5,
#  'search.audioburst.com': 5,
#  'sexyvintage80s.com': 5,
#  'supportaustralia.wordpress.com': 5,
#  'tang.skidmore.edu': 5,
#  'threadsmonthly.com': 5,
#  'timesofindia.indiatimes.com': 5,
#  'tropicalaffair.wordpress.com': 5,
#  'www.bella-cosmetica-eutin.de': 5,
#  'www.canstockphoto.com': 5,
#  'www.eyeglasses.com': 5,
#  'www.ffmpeg.org': 5,
#  'www.n4g.xyz': 5,
#  'www.railpage.com.au': 5,
#  'www.selhauling.com': 5,
#  'www.soccerbox.com': 5,
#  'www.t26.com': 5,
#  'www.theava.com': 5,
#  'zalbarath666.wordpress.com': 5,
#  'e-jurnal.pnl.ac.id': 4,
#  'fluffyfuzz.com': 4,
#  'foodformyfamily.com': 4,
#  'gallery.bizhat.com': 4,
#  'in1woord.nl': 4,
#  'moskwich.ru': 4,
#  'seandorseydance.com': 4,
#  '10dollarsluts.com': 4,
#  'angelallindseth.com': 4,
#  'b2b.shycreation.com': 4,
#  'birdwatchingalentejo.com': 4,
#  'bonnierussell.wordpress.com': 4,
#  'creoleindc.typepad.com': 4,
#  'ddfadventures.com': 4,
#  'e-discoveryteam.com': 4,
#  'freesexgames.cc': 4,
#  'knittingheadband.einsnummer.com': 4,
#  'lensscaper.wordpress.com': 4,
#  'luxurylifeways.com': 4,
#  'lyndamullalyhunt.wordpress.com': 4,
#  'm.audiobooks.com': 4,
#  'mohamadkarbi.com': 4,
#  'patrickrealstories.wordpress.com': 4,
#  'pila.it': 4,
#  'porngamesapp.com': 4,
#  'ruhlman.com': 4,
#  'santacruzfortucson.com': 4,
#  'spawnyspace.wordpress.com': 4,
#  'spicyonion.com': 4,
#  'stuffdutchpeoplelike.com': 4,
#  'theorangutanlibrarian.wordpress.com': 4,
#  'ttte.fandom.com': 4,
#  'upload.democraticunderground.com': 4,
#  'valihomotel.com': 4,
#  'www.axialentertainment.com': 4,
#  'www.balliol.ox.ac.uk': 4,
#  'www.balmessence.com': 4,
#  'www.courant.com': 4,
#  'www.customizesiliconewristbands.xyz': 4,
#  'www.dmt-nexus.me': 4,
#  'www.fangraphs.com': 4,
#  'www.freepik.com': 4,
#  'www.ineffableisland.com': 4,
#  'www.jerrysartarama.com': 4,
#  'www.jneurosci.org': 4,
#  'www.korg.com': 4,
#  'www.macleans.ca': 4,
#  'www.maharaniweddings.com': 4,
#  'www.morbidtattoo.com': 4,
#  'www.notarycoach.com': 4,
#  'www.onlinecounselling4u.com': 4,
#  'www.orientalexpress.co.uk': 4,
#  'www.sephora.com': 4,
#  'www.skatellsjewelers.com': 4,
#  'www.somethingforcake.com.au': 4,
#  'www.the-saleroom.com': 4,
#  'www.thecut.com': 4,
#  'www.therockstargallery.com': 4,
#  'www.wornforever.com': 4,
#  'chansuk.com': 3,
#  'chrisconnelly.me': 3,
#  'goabeachtourism.com': 3,
#  'horrormoviesuncut.com': 3,
#  'incestxxx.icu': 3,
#  'kumarkhareca.com': 3,
#  'locations.michaels.com': 3,
#  'michaelkusugak.editmy.website': 3,
#  'musicofporn.relayblog.com': 3,
#  'newsite.rebellegion.com': 3,
#  'paul-connolly.ie': 3,
#  'pornhud.org': 3,
#  'rushmoreacademy.com': 3,
#  'temanahok.com': 3,
#  'theliftiereport.rentskis.com': 3,
#  'writewithimages.com': 3,
#  'www.accomplishedwoman.us': 3,
#  'www.aggarwaldairyequipment.com': 3,
#  'www.bdqiangxing.com': 3,
#  'www.clicksmart.us': 3,
#  'www.emoryhealthsciblog.com': 3,
#  'www.girliascards.com': 3,
#  'www.mddriversalliance.org': 3,
#  'www.mykonosgrill.ca': 3,
#  'www.oilpulling.com': 3,
#  'www.redcarnewmarket.co.uk': 3,
#  'www.sfltimes.com': 3,
#  'www.sunindianporn.com': 3,
#  'www.thebolthole.org': 3,
#  '3movs.tube': 3,
#  'abcnews.go.com': 3,
#  'aircrashsites.co.uk': 3,
#  'amandacade.com': 3,
#  'anysex.com': 3,
#  'babyjungle.nl': 3,
#  'blondeambition.com.au': 3,
#  'charlottelondon.com': 3,
#  'clubs.scholastic.com': 3,
#  'cumshot.zone': 3,
#  'data.chattlibrary.org': 3,
#  'decoding.wordpress.com': 3,
#  'dshb.biology.uiowa.edu': 3,
#  'dundasplowingmatch.com': 3,
#  'excel.bigresource.com': 3,
#  'fbfl.us': 3,
#  'focusingonwildlife.com': 3,
#  'forum.2gn.org': 3,
#  'futuristrendcast.wordpress.com': 3,
#  'gaststaette-lurup.de': 3,
#  'greenprojectmanagement.info': 3,
#  'hotporn.sex': 3,
#  'ieddit.com': 3,
#  'iheartrecipes.com': 3,
#  'indianporn4k.com': 3,
#  'mariewilliams53.wordpress.com': 3,
#  'massagerepublic.com': 3,
#  'mom2fuck.mobi': 3,
#  'nationalpost.com': 3,
#  'ncrformsinvoices.ca': 3,
#  'noodle4president.wordpress.com': 3,
#  'onespoiledcat.wordpress.com': 3,
#  'pakistanporn.info': 3,
#  'philosophermouseofthehedge.wordpress.com': 3,
#  'pmc.com': 3,
#  'pommepal.wordpress.com': 3,
#  'practicalandrogyny.com': 3,
#  'rapepornxxx.net': 3,
#  'ronitpenso.wordpress.com': 3,
#  'route8auctions.com': 3,
#  'sexypigeons.com': 3,
#  'sportsmedsouth.com': 3,
#  'tvtropes.org': 3,
#  'viva.org.uk': 3,
#  'warehousespaces.com': 3,
#  'www.afristay.com': 3,
#  'www.animenewsnetwork.com': 3,
#  'www.audiofreebies.com': 3,
#  'www.benarijewelers.com': 3,
#  'www.bikefriday.com': 3,
#  'www.boulder-monitor.com': 3,
#  'www.comparehero.my': 3,
#  'www.concurrences.com': 3,
#  'www.dalgarnoinstitute.org.au': 3,
#  'www.earthflora.com': 3,
#  'www.elections.in': 3,
#  'www.everydaypets.com.au': 3,
#  'www.factinate.com': 3,
#  'www.franchiseindia.com': 3,
#  'www.goanews.com': 3,
#  'www.hup.harvard.edu': 3,
#  'www.icheckmovies.com': 3,
#  'www.inbetweenflights.com': 3,
#  'www.joinumi.com': 3,
#  'www.legislation.gov.au': 3,
#  'www.livejasmingirls.be': 3,
#  'www.livingalifeincolour.com': 3,
#  'www.monsports.com': 3,
#  'www.peony.mbgna.umich.edu': 3,
#  'www.phnompenhpost.com': 3,
#  'www.roopantaran.com': 3,
#  'www.scoliosis.org': 3,
#  'www.spreadshirt.net': 3,
#  'www.superdrug.com': 3,
#  'www.superiorstitch.net': 3,
#  'www.symeonidesfashion.com': 3,
#  'www.team-bhp.com': 3,
#  'www.youravon.com': 3,
#  'xnxxv.mobi': 3,
#  '4g.haoyun205.cn': 2,
#  'armchairgolfblog.blogspot.com': 2,
#  'bbs.vnl946k.cn': 2,
#  'bettywrightjones.com': 2,
#  'blog.yf2pdqj.cn': 2,
#  'blogs.mycentraljersey.com': 2,
#  'coloringbookstore.net': 2,
#  'educationist.com.pk': 2,
#  'ellicottvilletimes.com': 2,
#  'forum.woodenboat.com': 2,
#  'fulltimervers2.blogspot.com': 2,
#  'golftravelandleisure.com': 2,
#  'gorillafilmmagazine.com': 2,
#  'homeschool-curriculum-reviews.com': 2,
#  'lodzghetto.ago.ca': 2,
#  'm.facts-about.org.uk': 2,
#  'philipdoranthatcher.ie': 2,
#  'plppagerank.info': 2,
#  'reidnetjournal.blogspot.com': 2,
#  'upge.wn.com': 2,
#  'verifiedspace.com': 2,
#  'wanremona57603797.wikidot.com': 2,
#  'wip-thueringen.de': 2,
#  'www.10minutenovelists.com': 2,
#  'www.adandeliondiary.com': 2,
#  'www.bronzepie.com': 2,
#  'www.ckbartackova.cz': 2,
#  'www.content-technology.com': 2,
#  'www.federationcommander.com': 2,
#  'www.fenwaynation.com': 2,
#  'www.garyschwartzarthistorian.nl': 2,
#  'www.grannytubeclips.com': 2,
#  'www.jobz.pk': 2,
#  'www.mountainmancomics.com': 2,
#  'www.myrustica.com': 2,
#  'www.onrpg.com': 2,
#  'www.scarves-shawls-manufacturer.com': 2,
#  'www.snbbrewing.com': 2,
#  'www.tarrynfisher.com': 2,
#  'www.teenporntube.xxx': 2,
#  '3axis.co': 2,
#  'accentamerican.com': 2,
#  'aftershockcomics.com': 2,
#  'ahjav.com': 2,
#  'allmallshop.com': 2,
#  'anyporn.ink': 2,
#  'arstechnica.com': 2,
#  'auctions.mlb.com': 2,
#  'barbtaub.com': 2,
#  'bdocodex.com': 2,
#  'bebehblog.com': 2,
#  'bedfordwear.com': 2,
#  'biryani-master.blog': 2,
#  'blackbutterfly7.wordpress.com': 2,
#  'blutarsky.wordpress.com': 2,
#  'bookjotter.com': 2,
#  'brickwahl.com': 2,
#  'brilliantbikes.co.uk': 2,
#  'campuschildcare-old.wm.edu': 2,
#  'carboncostume.com': 2,
#  'crytoplusmining.com': 2,
#  'deadseriousness.com': 2,
#  'debsydaisy.com': 2,
#  'derobertiscaffe.com': 2,
#  'egetal.com.au': 2,
#  'ewing-gallery.utk.edu': 2,
#  'felthappiness.com': 2,
#  'femdom-videos.org': 2,
#  'footballfornormalgirls.com': 2,
#  'forum.flightgear.org': 2,
#  'forums.bharat-rakshak.com': 2,
#  'fulltummieshappyhearts.wordpress.com': 2,
#  'gajijukene.laikipiatourism.com': 2,
#  'geekmom.com': 2,
#  'giants.auctions.mlb.com': 2,
#  'git.claws-mail.org': 2,
#  'goodfridayimagess.com': 2,
#  'gotest.pk': 2,
#  'halo.bungie.net': 2,
#  'history.com': 2,
#  'homeopathybooks.in': 2,
#  'hundred-worries.com': 2,
#  'irc.queensu.ca': 2,
#  'johnguillen.wordpress.com': 2,
#  'kiltmaster.com': 2,
#  'learn.eyecheck.com': 2,
#  'lifeaslisaknowsit.com': 2,
#  'lovecraftzine.com': 2,
#  'maglaj.info': 2,
#  'mastersrankings.com': 2,
#  'matgostyles.com': 2,
#  'mininginnovationsafrica.com': 2,
#  'mrflawless.com': 2,
#  'net54baseball.com': 2,
#  'newenglandorchards.org': 2,
#  'nofoodjustwax.com': 2,
#  'norfolkislandcountrymusic.com': 2,
#  'northwoodaccountancy.co.uk': 2,
#  'onefinebaby.com.au': 2,
#  'owlmoonfarm.com': 2,
#  'pediatricspecialtypartners.com': 2,
#  'petticoatsandpistols.com': 2,
#  'photo.cate.blog': 2,
#  'pl.m.wikipedia.org': 2,
#  'pornok7.com': 2,
#  'preachitteachit.org': 2,
#  'progresspond.com': 2,
#  'psycheandnature.com': 2,
#  'purpletag.ie': 2,
#  'qa.studyfaq.com': 2,
#  'queenofareafive.wordpress.com': 2,
#  'ragsconsignments.com': 2,
#  'reddit.guide': 2,
#  'regulations.justia.com': 2,
#  'renewic.com': 2,
#  'res.blueskytours.globalbookingsolutions.com': 2,
#  'rosieamber.wordpress.com': 2,
#  'rubensteinphotography.com': 2,
#  'sarahstylesflorist.com': 2,
#  'savetube.org': 2,
#  'shopcahaba.com': 2,
#  'shoprala.com': 2,
#  'sissypantyshop.com': 2,
#  'sofabet.com': 2,
#  'sova.si.edu': 2,
#  'squirtbabes.net': 2,
#  'stacka-www.selfridges.com': 2,
#  'store.greennoiserecords.com': 2,
#  'studyboss.com': 2,
#  'sugacane.uk': 2,
#  'tevizz.com': 2,
#  'thefunkyflowershop.co.uk': 2,
#  'theperfumebox.com': 2,
#  'thesheaf.com': 2,
#  'usawatchdog.com': 2,
#  'useum.org': 2,
#  'valerieparente.com': 2,
#  'weheartmusic.typepad.com': 2,
#  'wikibruce.com': 2,
#  'workplace.stackexchange.com': 2,
#  'www.47rpg.com': 2,
#  'www.actionfigurebarbecue.com': 2,
#  'www.adabofgluewilldo.com': 2,
#  'www.adrianswinscoe.com': 2,
#  'www.afinoz.com': 2,
#  'www.allhomes.com.au': 2,
#  'www.americanfarriers.com': 2,
#  'www.antiquejewelrymall.com': 2,
#  'www.apropos-webserie.com': 2,
#  'www.aqualifeaquarium.com.au': 2,
#  'www.artevistas.eu': 2,
#  'www.australianpetshop.com.au': 2,
#  'www.bangbangoriental.com': 2,
#  'www.bastoni.com.au': 2,
#  'www.baynaturopath.co.nz': 2,
#  'www.beautiesltd.com': 2,
#  'www.beautycoiffure.com': 2,
#  'www.bendavidsonphotography.com': 2,
#  'www.besd.nl': 2,
#  'www.biblefunforkids.com': 2,
#  'www.bibliotica.com': 2,
#  'www.biodiversitylibrary.org': 2,
#  'www.biotherm.ca': 2,
#  'www.bourbonstreetphotography.com': 2,
#  'www.boutiquekolkata.com': 2,
#  'www.charleswoodflorist.com': 2,
#  'www.christopherterry.com': 2,
#  'www.citycentrequrum.com': 2,
#  'www.cloudcall.com': 2,
#  'www.collectionsetc.com': 2,
#  'www.congress.gov': 2,
#  'www.corporatefashion.co.za': 2,
#  'www.cx500forum.com': 2,
#  'www.dazzleme.com': 2,
#  'www.defencematrimony.com': 2,
#  'www.deliverancexorcisms.com': 2,
#  'www.dhgate.com': 2,
#  'www.dothanfirst.com': 2,
#  'www.dreamengine.com.au': 2,
#  'www.earthinfonow.com': 2,
#  'www.eco-tropicalresorts.com': 2,
#  'www.ecplaza.net': 2,
#  'www.electronic-cigarettesco.co.uk': 2,
#  'www.emptymirrorbooks.com': 2,
#  'www.epbot.com': 2,
#  'www.epiconlineshop.com': 2,
#  'www.essence.com': 2,
#  'www.eurogamer.net': 2,
#  'www.eurotunnel3.com': 2,
#  'www.financialgazette.co.zw': 2,
#  'www.fragrancedirect.co.uk': 2,
#  'www.free-ebooks.net': 2,
#  'www.gearhungry.com': 2,
#  'www.generativenlp.com': 2,
#  'www.getinlamka.com': 2,
#  'www.goesafrika.nl': 2,
#  'www.gothicmatch.com': 2,
#  'www.hallmark.com': 2,
#  'www.hema.com': 2,
#  'www.herbsdaily.com': 2,
#  'www.high-everydaycouture.com': 2,
#  'www.hotelamersfoorta1.nl': 2,
#  'www.housingalerts.com': 2,
#  'www.iferi.com': 2,
#  'www.intelligentquilting.com': 2,
#  'www.jadmadi.net': 2,
#  'www.jlsreport.com': 2,
#  'www.kidsinthehouse.com': 2,
#  'www.kirksvilledailyexpress.com': 2,
#  'www.kohinoorpropertystudio.com': 2,
#  'www.lawxpertsmv.com': 2,
#  'www.led-lamp-china.com': 2,
#  'www.littlewenlock.org': 2,
#  'www.loodgieter-reviews.nl': 2,
#  'www.mandolincafe.com': 2,
#  'www.maritimeprofessional.com': 2,
#  'www.medscape.com': 2,
#  'www.metalsucks.net': 2,
#  'www.morningadvertiser.co.uk': 2,
#  'www.myguideecuador.com': 2,
#  'www.mymoviepicker.com': 2,
#  'www.nestoria.co.uk': 2,
#  'www.nowrunning.com': 2,
#  'www.odysseybooks.com.au': 2,
#  'www.olympicpartyhire.com.au': 2,
#  'www.onemix.us': 2,
#  'www.pacificbulbsociety.org': 2,
#  'www.petdrugsonline.co.uk': 2,
#  'www.plussizeandsassy.com': 2,
#  'www.profitconfidential.com': 2,
#  'www.ramathorah.org': 2,
#  'www.rishteyads.com': 2,
#  'www.rockiesside.com': 2,
#  'www.rugsusa.com': 2,
#  'www.saatchigallery.com': 2,
#  'www.sacredheart.islington.sch.uk': 2,
#  'www.savacoolandsons.com': 2,
#  'www.selfridges.com': 2,
#  'www.sohomod.com': 2,
#  'www.somethingdifferentwholesale.co.uk': 2,
#  'www.stereokiller.com': 2,
#  'www.suffolkgazette.com': 2,
#  'www.sutroanusar.com': 2,
#  'www.svschinnen.nl': 2,
#  'www.theperfumespot.com': 2,
#  'www.thetaste.ie': 2,
#  'www.theworldofkrsmith.com': 2,
#  'www.turner-price.com': 2,
#  'www.urbancricketnyc.com': 2,
#  'www.vintagporntube.com': 2,
#  'www.vishopper.com': 2,
#  'www.vivaah.com': 2,
#  'www.voyage-prive.co.uk': 2,
#  'www.wblzmedia.com': 2,
#  'www.weegy.com': 2,
#  'www.westcoastbrewer.com': 2,
#  'www.woodandbeyond.com': 2,
#  'www.wowhd.co.uk': 2,
#  'www.zambesistore.com': 2,
#  'wwwkenterphotography.photoshelter.com': 2,
#  'xforum.live': 2,
#  '5amjoel.com': 1,
#  'allthingskaty.blogspot.com': 1,
#  'annanews.com': 1,
#  'anothernightelf.blogspot.com': 1,
#  'atcinsulators.com': 1,
#  'ava-max-sweet-but-psycho.vlastakahovcova.com': 1,
#  'axiv.cmsilsole.it': 1,
#  'azureclean.com': 1,
#  'baggiesbackpackers.com': 1,
#  'blog.crapandcrapability.com': 1,
#  'boxerkennelvarsenerhof.nl': 1,
#  'btownerrant.com': 1,
#  'caitlintrussell.org': 1,
#  'captaincomics.ning.com': 1,
#  'cdn.windows7download.com': 1,
#  'coloradovoters.info': 1,
#  'council.smallwarsjournal.com': 1,
#  'cwmags.co.uk': 1,
#  'dcpoetry.com': 1,
#  'dd.eionet.europa.eu': 1,
#  'duellinks.gamea.co': 1,
#  'fantasticforum.com': 1,
#  'fentazio.de': 1,
#  'foodjuggler.com': 1,
#  'forgotten-yesterdays.com': 1,
#  'forum.wotblitz.com': 1,
#  'ftp.us2.freshrpms.net': 1,
#  'geostore.tribalgathering.com': 1,
#  'goddesses-and-gods.blogspot.com': 1,
#  'heritain.club': 1,
#  'ig-gram.com': 1,
#  'ijstech.blogspot.com': 1,
#  'insideoutpr.com.au': 1,
#  'intocosmic.com': 1,
#  'irap.urbanjustice.org': 1,
#  'jobs.onestopindia.in': 1,
#  'johnredwoodsdiary.com': 1,
#  'lil-bo-peep.com': 1,
#  'local.sfgate.com': 1,
#  'lubs.name': 1,
#  'm.xxxhamer.com': 1,
#  'mason.ss10.sharpschool.com': 1,
#  'mexicocitylit.com': 1,
#  'mintgoldbar.com': 1,
#  'monkeysnchickens.blogspot.com': 1,
#  'montgomeryconcretecontractor.com': 1,
#  'netlibrary.ws': 1,
#  'neweconomicperspectives.org': 1,
#  'newzeal.blogspot.com': 1,
#  'omnianews.com': 1,
#  'openfiredesign.com': 1,
#  'peuterspeelzaalpinkeltje.nl': 1,
#  'planning.newport.gov.uk': 1,
#  'printablecoloringpagesforkids.net': 1,
#  'rapparles.com': 1,
#  'readsbookonline.com': 1,
#  'rotola.blogspot.com': 1,
#  'sail.zezo.org': 1,
#  'savygamer.blogspot.com': 1,
#  'schenzacu.webcindario.com': 1,
#  'sfappeal.com': 1,
#  'shoeboutique.net.au': 1,
#  'smilethesmile.blogspot.com': 1,
#  'snowdropfoundation.org': 1,
#  'spaceksc.blogspot.com': 1,
#  'sparkrecipes.sparkpeople.com': 1,
#  'stylegang.in': 1,
#  'sweetsoundtrack.com': 1,
#  'teknosounds.com': 1,
#  'topfishingcalifornia.com': 1,
#  'twofinechaps.com': 1,
#  'wiki.eclipse.org': 1,
#  'wolfgang-pfeifer.info': 1,
#  'www.adtechamm.com': 1,
#  'www.allsportspk.com': 1,
#  'www.alternatiefbeterworden.nl': 1,
#  'www.anagonzales.com': 1,
#  'www.annarborderm.com': 1,
#  'www.athinkingstomach.com': 1,
#  'www.avolsenchem.com': 1,
#  'www.ayearofbeinghere.com': 1,
#  'www.bestmascots.com': 1,
#  'www.bijoulovelydesigns.com': 1,
#  'www.brandarling.com': 1,
#  'www.bryangale.com': 1,
#  'www.china-cart.com': 1,
#  'www.cityofknoxville.org': 1,
#  'www.classictvsports.com': 1,
#  'www.digitaljournal.com': 1,
#  'www.diyhometutorials.com': 1,
#  'www.drclaudia.net': 1,
#  'www.drjack.co.uk': 1,
#  'www.duckandrun5k.com': 1,
#  'www.eatbydate.com': 1,
#  'www.ectaco.co.uk': 1,
#  'www.epochresidential.com': 1,
#  'www.fpl-dugout.co.uk': 1,
#  'www.freeismylife.com': 1,
#  'www.freepatchworkquiltinfo.com': 1,
#  'www.getbeststuff.com': 1,
#  'www.greatancheta.com': 1,
#  'www.gwfc18.com': 1,
#  'www.hsfmanual.com': 1,
#  'www.isslup.org': 1,
#  'www.jamesweggreview.org': 1,
#  'www.jewelsbysimpson.com': 1,
#  'www.jiz-18.com': 1,
#  'www.jnht.com': 1,
#  'www.junkytrinkets.com': 1,
#  'www.kastlekare.com': 1,
#  'www.khavhotours.com': 1,
#  'www.koolkidzice.com': 1,
#  'www.korda.co.uk': 1,
#  'www.maneghost.com': 1,
#  'www.marbleslabguys.com': 1,
#  'www.michaelandsonhelpinghands.com': 1,
#  'www.mindlessmumbai.com': 1,
#  'www.mrandmrspowell.com': 1,
#  'www.muchlovesara.com': 1,
#  'www.nesca-news.com': 1,
#  'www.nikforrest.net': 1,
#  'www.nysm.nysed.gov': 1,
#  'www.pakclassified.com': 1,
#  'www.perfectingthepairing.com': 1,
#  'www.picslyrics.net': 1,
#  'www.podles.org': 1,
#  'www.poterie-merccion.fr': 1,
#  'www.propbay.com': 1,
#  'www.pxleyes.com': 1,
#  'www.quimperantiques.com': 1,
#  'www.rutea.com': 1,
#  'www.sarmsteroid.com': 1,
#  'www.sheryllynnfoundation.org': 1,
#  'www.snugglyoranges.com': 1,
#  'www.sternenvironmental.com': 1,
#  'www.takingpaws.com': 1,
#  'www.theatrescenes.co.nz': 1,
#  'www.toontricks.com': 1,
#  'www.tooyarncute.com': 1,
#  'www.usabassin.com': 1,
#  'www.wardogmemorialfund.com': 1,
#  'www.weservekc.org': 1,
#  'www.whereapy.com': 1,
#  'www.winecreations.biz': 1,
#  'www.youaretheriver.com': 1,
#  'www4.oldies.com': 1,
#  '2ksex.com': 1,
#  '45miniatures.com': 1,
#  '580wksk.com': 1,
#  'admin.wedmegood.com': 1,
#  'admissions.dpu.edu.in': 1,
#  'affordabledoorsandgates.com': 1,
#  'allfreegay.com': 1,
#  'allinfonepal.com': 1,
#  'alloemaudiparts.com': 1,
#  'almet-kultura.ru': 1,
#  'alt.cc': 1,
#  'andrea-gomoll.de': 1,
#  'animalcare.lacounty.gov': 1,
#  'answers.opencv.org': 1,
#  'apinchofhomestead.com': 1,
#  'apops.mas.org': 1,
#  'applianceparts.lowes.com': 1,
#  'area51.stackexchange.com': 1,
#  'artmuseum.mtholyoke.edu': 1,
#  'asermetal.fr': 1,
#  'asiatimes.com': 1,
#  'assets.macysassets.com': 1,
#  'authorscanvas.blog': 1,
#  'auto-dvrs.ru': 1,
#  'barbarana.threadless.com': 1,
#  'beckereyecare.com': 1,
#  'benedictsutton.com': 1,
#  'benpursellphotography.com': 1,
#  'beta.e-justice.europa.eu': 1,
#  'betonstudio.com': 1,
#  'bge-training.com': 1,
#  'bibletruthpublishers.com': 1,
#  'bid.elstobandelstob.co.uk': 1,
#  'big-peremena.ru': 1,
#  'billingadventure.com': 1,
#  'bingato.com': 1,
#  'bitchin-fiction.com': 1,
#  'blackbrigade.org': 1,
#  'blog.craftbeercellar.com': 1,
#  'blog.seattlepi.com': 1,
#  'blowoutbuzz.wordpress.com': 1,
#  'boltontravel.com': 1,
#  'books.google.com.pk': 1,
#  'books.google.mk': 1,
#  'boywithgrenade.org': 1,
#  'bridgeportisd.net': 1,
#  'brignews.com': 1,
#  'bronx.com': 1,
#  'burgersandboardingpasses.com': 1,
#  'burnoutvintage.com': 1,
#  'businessfinder.nj.com': 1,
#  'businesstech.co.za': 1,
#  'ca.dessy.com': 1,
#  'caitlinmcgowan.threadless.com': 1,
#  'callofduty.fandom.com': 1,
#  'caltongallery.co.uk': 1,
#  'capitalsoutsider.com': 1,
#  'carbuzz.com': 1,
#  'carterscompost.com': 1,
#  'catalog.waldenu.edu': 1,
#  'chaturbate.monster': 1,
#  'chinatel.us': 1,
#  'chocolaterie-bonnevie.fr': 1,
#  'chs.comfortisd.org': 1,
#  'cide.academic.ru': 1,
#  'citysonnet.wordpress.com': 1,
#  'clarkstonnews.com': 1,
#  'classicroverforum.net': 1,
#  'clayandessence.com': 1,
#  'club.chicacircle.com': 1,
#  'createwithcynthia.com': 1,
#  'creativescollege.net': 1,
#  'creditboards.com': 1,
#  'cristianmihai.net': 1,
#  'crossingstation.com': 1,
#  'crumbleco.com': 1,
#  'darrencalabrese.com': 1,
#  'daughtersofdivinepower.com': 1,
#  'dawnsutti.com': 1,
#  'daylinews.de': 1,
#  'dblp.dagstuhl.de': 1,
#  'dbreun.de': 1,
#  'dealsdom.com': 1,
#  'delhiair.org': 1,
#  'digitalmastery.com': 1,
#  'directory.luton.gov.uk': 1,
#  'dirt.asla.org': 1,
#  'discountstaging.com': 1,
#  'diva.sfsu.edu': 1,
#  'djpunjab-gaana.com': 1,
#  'docs.ont.io': 1,
#  'dolanlawfirm.com': 1,
#  'doublethecuddles.wordpress.com': 1,
#  'dreams-dragons.blogspot.com': 1,
#  'dreamweaver333.com': 1,
#  'dumpsters-nc.com': 1,
#  'earthlife.org.za': 1,
#  'echa.europa.eu': 1,
#  'ecocbdvape.com': 1,
#  'egilkison.threadless.com': 1,
#  'emily-b.net': 1,
#  'emilydonaldson.com': 1,
#  'en.mixxmix.com': 1,
#  'en.useahimsa.com': 1,
#  'eoinmurray.org': 1,
#  'erickimphotography.com': 1,
#  'erineph.com': 1,
#  'etrakr.net': 1,
#  'eu.huntbikewheels.com': 1,
#  'eune.op.gg': 1,
#  'ewenbell.com': 1,
#  'fairyprincessdiaries.com': 1,
#  'fellmonger.in': 1,
#  'fernandoceja.com': 1,
#  'fineartamerica.com': 1,
#  'firstnightdesign.wordpress.com': 1,
#  'fitchburgpride.com': 1,
#  'forum.allaboutcircuits.com': 1,
#  'forum.wotlabs.net': 1,
#  'forum.zenstudios.com': 1,
#  'forums.moneysavingexpert.com': 1,
#  'forums.thesmartmarks.com': 1,
#  'fr-en.openfoodfacts.org': 1,
#  'freshmms.icu': 1,
#  'frompemberleytomilton.wordpress.com': 1,
#  'fsne.org': 1,
#  'fwo3.com': 1,
#  'fyi.cityoflondon.gov.uk': 1,
#  'gadgetguideonline.com': 1,
#  'gahistoricnewspapers.galileo.usg.edu': 1,
#  'galacticgladiators.com': 1,
#  'game-curator.com': 1,
#  'gayteenporn.tv': 1,
#  'geekhack.org': 1,
#  'gepnic.gov.in': 1,
#  'gifimage.net': 1,
#  'gmdrives.com': 1,
#  'greerchesher.com': 1,
#  'greyflash2751.com': 1,
#  'gygaqogerizywiq.niarbylbaycafe.com': 1,
#  'hamptonsemployment.com': 1,
#  'harvestag.com': 1,
#  'hatstacksonline.com': 1,
#  'hautemessonline.com': 1,
#  'health.economictimes.indiatimes.com': 1,
#  'heartlandyogafestival2019.sched.com': 1,
#  'heavy.com': 1,
#  'heiressllc.com': 1,
#  'herdogblog.com': 1,
#  'hivemodern.com': 1,
#  'houseofheartweb.wordpress.com': 1,
#  'iammaurina.com': 1,
#  'iifd.in': 1,
#  'ildrm.com': 1,
#  'imamsonline.com': 1,
#  'it-atwork.co.uk': 1,
#  'itsahalallife.com': 1,
#  'izmirescort.pro': 1,
#  'jadedphotography.wordpress.com': 1,
#  'jayrobb.me': 1,
#  'jeffgreenphoto.com': 1,
#  'jennymslattery.com': 1,
#  'jobs.designengine.com': 1,
#  'jonellepatrick.me': 1,
#  'journalofdawn.wordpress.com': 1,
#  'juwiqybalyny.maghreb-healthexpo.com': 1,
#  'karanfoodfanatic.com': 1,
#  'kennywiley.com': 1,
#  'keziacole.threadless.com': 1,
#  'kids-gift-ideas.com': 1,
#  'kikay.shop': 1,
#  'kulinarie.ru': 1,
#  'lavenderlodgegp.co.za': 1,
#  'lawyers.oyez.org': 1,
#  'leelinesourcing.com': 1,
#  'leenlovesstyle.com': 1,
#  'lesote.com': 1,
#  'lib.dr.iastate.edu': 1,
#  'lifetapestrycreations.wordpress.com': 1,
#  'likeabostblog.com': 1,
#  'likemotherlikedaughter2016.wordpress.com': 1,
#  'lindacassidylewis.com': 1,
#  'lisaoflongbourn.wordpress.com': 1,
#  'listography.com': 1,
#  'littlebertha.com.au': 1,
#  'livethelive.com': 1,
#  'livingston-appliance-repairs.co.uk': 1,
#  'logan-hardware.com': 1,
#  'lolairis.com.au': 1,
#  'lookbook.nu': 1,
#  'loyaltylobby.com': 1,
#  'lucybrydonart.com': 1,
#  'lwhosting.biz': 1,
#  'malaysia.news.yahoo.com': 1,
#  'manchesteruniversitypress.co.uk': 1,
#  'marketingdiscussions.wordpress.com': 1,
#  'martyrboy.threadless.com': 1,
#  'mattcremona.com': 1,
#  'matthiasclamer.com': 1,
#  'matureporn.watch': 1,
#  'mckaysbakery.com': 1,
#  'medicine.careers360.com': 1,
#  'metryicentymetry.pl': 1,
#  'mimicrawfordblog.com': 1,
#  'mobileporn.sexto.mobi': 1,
#  'modernize.com': 1,
#  'modernwarriors.com': 1,
#  'moviesanywhere.com': 1,
#  'nancy-c.com': 1,
#  'nancyhoytbelcher.com': 1,
#  'newatlas.com': 1,
#  'news.illinois.edu': 1,
#  'nixers.net': 1,
#  'nohredcross.org': 1,
#  'northernwestchesteroms.com': 1,
#  'notquiteold.com': 1,
#  'offcutsshoes.co.uk': 1,
#  'omgshirts.net': 1,
#  'p13n-bloomsbury.highwire.org': 1,
#  'pajaronerds.com': 1,
#  'parting.gifts': 1,
#  'payadsocial.com': 1,
#  'peopleskateandsnowboard.com': 1,
#  'pexlives.libsyn.com': 1,
#  'planetcocoon.com': 1,
#  'player.fm': 1,
#  'plymagazine.com': 1,
#  'po.missouri.edu': 1,
#  'popcornobsession.com': 1,
#  'portsarecalling.com': 1,
#  'poshmark.ca': 1,
#  'powersforthepeople.net': 1,
#  'precision.agwired.com': 1,
#  'prestigeglassware.com': 1,
#  'prestogifts.com': 1,
#  'primecomputer.co': 1,
#  'priyahuffman.com': 1,
#  'products.kitsapsun.com': 1,
#  'projectophile.net': 1,
#  'psbwritingcenter.org': 1,
#  'publicfaq.hotelsetc.com': 1,
#  'randallbeans.com': 1,
#  'react.statuscode.com': 1,
#  'readthespirit.com': 1,
#  'reallifecam.monster': 1,
#  'resourceroom.co.nz': 1,
#  'risdmuseum.org': 1,
#  'rlorensandford.com': 1,
#  'rnzaoc.com': 1,
#  'roccuzzorealty.com': 1,
#  'rockminetv.wordpress.com': 1,
#  'rocksubculture.com': 1,
#  'rotoruaheatoutdoors.nz': 1,
#  'rsisdev.ramsar.org': 1,
#  'rsistest.ramsar.org': 1,
#  'rsmus.com': 1,
#  'rts.fantasyalarm.com': 1,
#  'sahoco.com': 1,
#  'sailinganarchy.com': 1,
#  'salonstore.com': 1,
#  'sandyrosencrans.com': 1,
#  'sarkariexamhub.in': 1,
#  'sbfantasyleague.league.fantasy.nfl.com': 1,
#  'scepticemia.com': 1,
#  ...}

# %%
len({k: v for k, v in pornsites.items() if v > 1})
# Out:
# 262

# %%
204.00/12903.00
# Out:
# 0.015810276679841896
