# %%
#!/usr/bin/env python
import os
from witb.utils import ioutils as io
from witb.globals import DATA_DIR
import time  
import nltk
import csv
import re, string
import collections
from collections import Counter
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import datetime

# %%
stop_words = set(stopwords.words('english'))

# %%
DATA_DIR="/home/sasha/Documents/MilaPostDoc/Python/CommonCrawl"

# %%
profane='wordlists/profane_words.txt'

# %%
profanelist = []
with open(profane, newline='') as inputfile:
    for row in inputfile:
        profanelist.append(row.strip())
print(len(profanelist))
# Out:
# 1383

# %%
profanelist[5]
# Out:
# 'addicts'

# %%
filenames = os.listdir(DATA_DIR)
filename = os.path.join(DATA_DIR, filenames[0])

data = io.get_entries(io.read_wet_file(filename))
parsed_data = io.parse_data(data)  # Generator.

docs = []
start_time = time.time()
for doc in parsed_data:
    docs.append(doc)

# %%
for doc in docs:
    if doc.url=='www.twinkpornvideo.com':
        testdoc=doc.content

# %%
testdoc
# Out:
# "View Park-Windsor Hills ts hookers, hook up - Twink Porn ✔️\nTWINK PORN\nHookers\nUnited States\nCalifornia\nView Park-Windsor Hills\nTs hookers View Park-Windsor Hills\nAmanda carey trans 22x4 passing through View Park-Windsor Hills 15 th for curious straight men\nTs hook up View Park-Windsor Hills\nHello everyone, I am Amanda Carey Brazilian from passag in View Park-Windsor Hills 15 EME I am active and passive. Call me for more information thanks to all of you kisses.\nParty duo your best option to make a rich trio\nView Park-Windsor Hills escort incall\nOnly a couple of scorts a beautiful girl trans gifted i morbid i a handsome guy very gifted we are very party we like the morbid and much sex we are dominant i very affectionate at the time\nKaren trans 20 cm 100% real\nView Park-Windsor Hills ts hook up\nHello darling, 200% real and NO SURPRISES ON PLACE I'm Karen, Pretty new latina in the corner. I offer you to spend divine moments with me, I am expert and gentle for beginners and I love new experiences. I like to have a good and charming time without hurry, we will take the time we need for fun. I have no taboo, wild with demanding people. What are you waiting for? Call me!\nArianna news in View Park-Windsor Hills arrives from Brazil\nTs View Park-Windsor Hills incalls escort\nHello .. I'm Arianna, a beautiful transsexual 22 years old with a beautiful surprise of 20cm, blond hair, always in a good mood smiling and elegant cultivated open cultured I offer you beautiful moments of pleasant and warm company! I am waiting for you! Thank you for making an appointment in advance! I am very feminine and very sexy Size: a physical sculpted in the gym, XL buttocks, 170 cm high, 65 kg 44 bust and 20cm of great pleasure! I love lingerie and femininity! Details about my services are available in simple call\nMilf nymphomaniac sex specialist\nHookers View Park-Windsor Hills\nBeautiful MILF nympho trans, sexy and naughty with everything you are looking for. Complete, I make your fantasies come true or I'll be your girlfriend, how can I devour you with a lot of desire, kiss your mouth with my hot and wet mouth and a greedy tongue. Come and meet me, let's enjoy unique moments! I am complete and full of desire of refined and tasteful men. I also accept couples. My location is discreet, comfortable and safe. Call 20 minutes before our meeting, we will live unforgettable moments! Kisses, Monique Mon\nTrans laura mariane passage to View Park-Windsor Hills\nProstitutes View Park-Windsor Hills\nLAURA TRANS SUPER ACTV BM/ TS 22X5 ***100% REAL PICTURES*** ⭐DISPONIBLE FROM 10:00 AM IN THE MORNING 10:00 PM *** ⭐RENDEZ YOU 30 MIN BEFORE *** Hi everyone, I'm going to introduce myself to you. My name is LAURA, I'm a beautiful Brazilian transgender, 22 years old. 1,78m 66kg. With a SURPRISE of 22x5 c m R E L for you, and B E A U C O U P - D E - S P E R M E . Sexy, soft, refined and sublime. I LOVE BEGINNERS! I propose you a meeting like no one has ever proposed you before. My delicacy is my main strong point. My photos are 100% real I offer you a quality service, discreet and confidential... I receive you in a very nice apartment, central, neat, pleasant, discreet and well decorated. All right, guys, I hope you know a little more about me and invite a meeting because we still have a lot to get to know each other. (I don't answer hidden calls) Kisses LAURA MARIANE\nMariana trans\nView Park-Windsor Hills outcalls escort\nBeautiful mariana to you. I am very well known in all the safe, feminine and sweet way. If you are looking for something really special and a little different, a little adventure to help you forget your daily worries and the stress of living, then I am here for you. Discreet, elegant. I am a classy and beautiful transsexual. I am sensitive and really interested and give you the best.\nBeautiful sexy trans métisse crossing over\nTs escort girl View Park-Windsor Hills\nHi, I'm Lola a Pretty Hot New Trans Coquine here.I like Tenderness, S ...

# %%
#Simple word search
start = time.time()
pornsites={}
for doc in docs:
    clean = [w.strip(string.digits + string.punctuation).lower() for w in word_tokenize(doc.content) if w not in stop_words]
    pwds=len([w for w in word_tokenize(doc.content) if w in profanelist])
    pornsites[doc.url]=pwds
duration=str(datetime.timedelta(seconds=time.time() - start))
print("Number of pages counted: ", len(pornsites))
print("Duration: ", duration)

# %%
#Bigram search
stop_words = set(stopwords.words('english'))  
start = time.time()
pornsites={}
for doc in docs:
    clean = [w.strip(string.digits + string.punctuation).lower() for w in word_tokenize(doc.content) if w not in stop_words]
    bigrams=[b for b in nltk.bigrams(word_tokenize(str(' '.join(clean))))]
    match = set(bigrams).intersection(bigramlist)
    pornsites[doc.url]=len(match)
duration=str(datetime.timedelta(seconds=time.time() - start))
print("Number of pages counted: ", len(pornsites))
print("Duration: ", duration)
# Out:
# Number of pages counted:  12903
# Duration:  0:04:14.038242

# %%
#Bigram search
stop_words = set(stopwords.words('english'))  
start = time.time()
pornsites={}
for doc in docs:
    clean = [w.strip(string.digits + string.punctuation).lower() for w in word_tokenize(doc.content) if w not in stop_words]
    bigrams=[b for b in nltk.bigrams(word_tokenize(str(' '.join(clean))))]
    match = set(bigrams).intersection(bigramlist)
    pornsites[doc.url]=[len(match), str(match)]
duration=str(datetime.timedelta(seconds=time.time() - start))
print("Number of pages counted: ", len(pornsites))
print("Duration: ", duration)

# %%
{k: v for k, v in sorted(pornsites.items(), key=lambda item: item[1], reverse=True)}
# Out:
# {'www.pornhavana.com': 107,
#  'pinoyplushd.com': 74,
#  'www.allviewfunding.com': 64,
#  'www.fapmovs.tv': 62,
#  'musicofporn.relayblog.com': 52,
#  'www.sunindianporn.com': 51,
#  'verifiedspace.com': 43,
#  'annaazizah.ilearning.me': 41,
#  'prn247.com': 41,
#  'www.shinyakushiji.or.jp': 41,
#  'cumshot.zone': 40,
#  'hotporn.sex': 40,
#  'indianporn4k.com': 40,
#  '2ksex.com': 39,
#  'dev.radiantnepal.com': 34,
#  'hoetoob.com': 33,
#  'pornokim.com': 31,
#  'xxxvidso.com': 31,
#  'ebonyporn.site': 29,
#  'penisextendersonreview.com': 28,
#  'wellnesscarefoundation.com': 28,
#  'www.momtubexxx.com': 27,
#  'www.teenporntube.xxx': 27,
#  'family-tube.hq-prn.com': 26,
#  'www.mofoscasting.com': 26,
#  'www.vintagporntube.com': 25,
#  'allfreegay.com': 24,
#  'matureporn.watch': 24,
#  'originalhindiporn.mobi': 24,
#  'pornok7.com': 23,
#  'stillwissen.com': 23,
#  'teenpussysex.net': 23,
#  'sexyvintage80s.com': 22,
#  'www.flashonthebeach.com': 21,
#  'topincestvideos.com': 21,
#  'bibviz.com': 20,
#  'incestxxx.icu': 20,
#  'www.xn--80aafblbgpxxcgbigyfoeei.xn--p1ai': 20,
#  'freesexgames.cc': 20,
#  'maglaj.info': 19,
#  'writewithimages.com': 18,
#  'www.hotsexymothers.com': 18,
#  'www.grannytubeclips.com': 17,
#  'ddfadventures.com': 17,
#  'lolcow.farm': 17,
#  'mncarpetcleaners.info': 17,
#  'nancyhoytbelcher.com': 17,
#  'pornoteen.me': 17,
#  'xnxxv.mobi': 17,
#  'youjizz.site': 17,
#  'fuckfreetube.com': 16,
#  'mexicocitylit.com': 16,
#  'anyporn.ink': 16,
#  'www.gaymovies5.com': 16,
#  '45miniatures.com': 15,
#  'asianpornhd.me': 15,
#  'bingato.com': 15,
#  'diablotube.mobi': 15,
#  'norfolkislandcountrymusic.com': 15,
#  'rapepornxxx.net': 15,
#  'www.fapjapan.info': 14,
#  '3movs.tube': 14,
#  'afiporn.net': 14,
#  'porngamesapp.com': 14,
#  'santacruzfortucson.com': 14,
#  'tubenza.mobi': 14,
#  'bobolike.com': 13,
#  'pakistanporn.info': 13,
#  'www.grannybigboobs.com': 13,
#  'www.livejasmingirls.be': 13,
#  'xxxxvideo.casa': 13,
#  'yourbunny.mobi': 13,
#  'temanahok.com': 12,
#  'acuptube.com': 12,
#  'femdom-videos.org': 12,
#  'www.delightcam.com': 12,
#  'tubematurefree.com': 11,
#  'zerox.com.ng': 11,
#  'mobileporn.sexto.mobi': 11,
#  'tophentaicomics.com': 11,
#  'bloommetal.com': 10,
#  'henriettacreekorchard.com': 10,
#  'pornhud.org': 10,
#  'culturakholmsk.ru': 10,
#  'goodfridayimagess.com': 10,
#  'johnelite.com': 10,
#  'tutuapphelperapk.com': 10,
#  'www.unrulydude.com': 10,
#  'xcafe.com': 10,
#  'gorillafilmmagazine.com': 9,
#  'slimteensex.com': 9,
#  'softpornsifi.amandahot.com': 9,
#  'www.fetishporntube.eu': 9,
#  'chinatel.us': 9,
#  'fanfaps.com': 9,
#  'freepornxxx.co': 9,
#  'freesex24.pro': 9,
#  'greenprojectmanagement.info': 9,
#  'machineasexe.com': 9,
#  'reallifecam.monster': 9,
#  'sexypigeons.com': 9,
#  'www.coupons.xxx': 9,
#  'www.rockiesside.com': 9,
#  'yespornplease.name': 9,
#  'plppagerank.info': 8,
#  'twofinechaps.com': 8,
#  'www.trannyxvideos.com': 8,
#  'anysex.com': 8,
#  'kamafantasy.com': 8,
#  'momsuckxxx.com': 8,
#  'redrube.mobi': 8,
#  'www.crazydaysandnights.net': 8,
#  'chrisconnelly.me': 7,
#  'topbellydancer.com': 7,
#  'www.andjusticeforart.com': 7,
#  'adultvibetoys.com': 7,
#  'casualsexproject.com': 7,
#  'gayteenporn.tv': 7,
#  'massagerepublic.com': 7,
#  'tinhdaungocthao.com': 7,
#  'www.ukdogging.co': 7,
#  'd4r8m3c7.ssl.hwcdn.net': 6,
#  'lip2014.eu': 6,
#  'mom2fuck.mobi': 6,
#  'nailsideas.site': 6,
#  'paularenee.wordpress.com': 6,
#  'teens-livesex.com': 6,
#  'teens.community': 6,
#  'www.lovematic.ie': 6,
#  'blog.gaymassagevideos.com': 5,
#  'horrormoviesuncut.com': 5,
#  'm.xxxhamer.com': 5,
#  'postrickland.com': 5,
#  'smashyroadcheats.site': 5,
#  't-central.blogspot.com': 5,
#  'www.jiz-18.com': 5,
#  'almet-kultura.ru': 5,
#  'big-peremena.ru': 5,
#  'freesexgames.club': 5,
#  'grayfantasy.ru': 5,
#  'iammaurina.com': 5,
#  'squirtbabes.net': 5,
#  'www.bizarreporntube.com': 5,
#  'www.freemompornvideos.com': 5,
#  'www.organizedschoolbinder.com': 5,
#  'www.sexshopusa.org': 5,
#  'www.sutroanusar.com': 5,
#  'xnnx.best': 5,
#  'xxxvideosdownload.ru': 5,
#  'contentedmotion.com': 4,
#  'insecure.archiveofourown.org': 4,
#  'seattlespetvet.com': 4,
#  'www.cloverfieldnews.com': 4,
#  'www.xxxfilms.xxx': 4,
#  '10dollarsluts.com': 4,
#  'ahjav.com': 4,
#  'auto-dvrs.ru': 4,
#  'fantageville.wordpress.com': 4,
#  'halfchinese.org': 4,
#  'italiablog.online': 4,
#  'painfulpussytortures.com': 4,
#  'www.deliverancexorcisms.com': 4,
#  'www.lovehoney.eu': 4,
#  'www.wowcustomersupport.com': 4,
#  'xvideossexxx.com': 4,
#  'xxx.paypergay.com': 4,
#  'xxxvideios.net': 4,
#  'galleries.imctrck.com': 3,
#  'intocosmic.com': 3,
#  'sergesblog.blogspot.com': 3,
#  'www.condomsaustralia.com.au': 3,
#  'www.johnnyfavoritesnyc.com': 3,
#  'www.pornmobilepass.com': 3,
#  'www.secretpleasuresboutique.com': 3,
#  'www.youjizz777.com': 3,
#  'auto-tomsk.ru': 3,
#  'blonde-videos.com': 3,
#  'freshmms.icu': 3,
#  'ieddit.com': 3,
#  'lifestyle.ng': 3,
#  'longlife-stavni.ru': 3,
#  'patrickrealstories.wordpress.com': 3,
#  'trendingtodaysnews.com': 3,
#  'txxxmstudios.com': 3,
#  'voyeurtubevideos.com': 3,
#  'www.apropos-webserie.com': 3,
#  'www.covertpleasures.com': 3,
#  'www.twinkpornvideo.com': 3,
#  'zalbarath666.wordpress.com': 3,
#  'cdn.windows7download.com': 2,
#  'fantasybookcritic.blogspot.com': 2,
#  'frantonios.org.au': 2,
#  'gzsd.stazioneserviziodemi.it': 2,
#  'mychristiandiary.blogspot.com': 2,
#  'newlineporn.com': 2,
#  'schenzacu.webcindario.com': 2,
#  'www.deckert.org': 2,
#  'www.hornyxxxtube.com': 2,
#  'www.mddriversalliance.org': 2,
#  'www.sfltimes.com': 2,
#  'www.ugtsiut.org': 2,
#  'alessiomichelini.com': 2,
#  'analamateur.me': 2,
#  'cammodeldirectory.com': 2,
#  'djpunjab-gaana.com': 2,
#  'domaine-peyronnet.com': 2,
#  'domizil-gesundheitsclub.de': 2,
#  'ewenbell.com': 2,
#  'heavy.com': 2,
#  'jadedphotography.wordpress.com': 2,
#  'jannatwrites.wordpress.com': 2,
#  'jayspov.net': 2,
#  'josephsmithfoundation.org': 2,
#  'levitraprice.site': 2,
#  'lovecraftzine.com': 2,
#  'matgostyles.com': 2,
#  'mbdou-19-41.ru': 2,
#  'modc9.site': 2,
#  'newmediarockstars.com': 2,
#  'pdfsecret.com': 2,
#  'pornhu.vip': 2,
#  'psycheandnature.com': 2,
#  'rabalaishomes.com': 2,
#  'shannonsdreams.wordpress.com': 2,
#  'shermanave.wordpress.com': 2,
#  'skymoviehd.net': 2,
#  'sofabet.com': 2,
#  'survivalsherpa.wordpress.com': 2,
#  'taylorholmes.com': 2,
#  'thebloggess.com': 2,
#  'thislandisparkland.com': 2,
#  'tvtropes.org': 2,
#  'vigil360.com.ng': 2,
#  'worldfilm4u.com': 2,
#  'worldnews.su': 2,
#  'www.adrianswinscoe.com': 2,
#  'www.adswiki.co': 2,
#  'www.analibiza.com': 2,
#  'www.bibliotica.com': 2,
#  'www.chaydinxxx.com': 2,
#  'www.clubdechicos.com': 2,
#  'www.elitedaily.com': 2,
#  'www.enchantedpleasures.com': 2,
#  'www.financedirectory.biz': 2,
#  'www.flumc.org': 2,
#  'www.freepik.com': 2,
#  'www.fultonschools.org': 2,
#  'www.japanfemdom.org': 2,
#  'www.madariaga-mp.com': 2,
#  'www.markbland.net': 2,
#  'www.moonofalabama.org': 2,
#  'www.nkytribune.com': 2,
#  'www.pinkbasis.com': 2,
#  'www.remodelaholic.com': 2,
#  'www.seiu99.org': 2,
#  'www.sevendaysvt.com': 2,
#  'www.sexyboobies.net': 2,
#  'www.strawbale.com': 2,
#  'www.techgalatta.xyz': 2,
#  'www.texasbaseballranch.com': 2,
#  'www.vanielje.com': 2,
#  'ybuholdings.com': 2,
#  '1966mag.com': 1,
#  '987thecoast.com': 1,
#  'adultinternetusers.com': 1,
#  'alldolledup.co.za': 1,
#  'amerywisconsin.net': 1,
#  'androidfc.com': 1,
#  'anthillonline.com': 1,
#  'armchairgolfblog.blogspot.com': 1,
#  'armjisoft.com': 1,
#  'astrologyclub.org': 1,
#  'ava-max-sweet-but-psycho.vlastakahovcova.com': 1,
#  'bbs.vnl946k.cn': 1,
#  'chong-mail.net': 1,
#  'climo.fitunlife.com': 1,
#  'commentpics.in': 1,
#  'cookdayclub.com': 1,
#  'cprc-sf.org': 1,
#  'creationcrave.com': 1,
#  'darkroom.baltimoresun.com': 1,
#  'e-jurnal.pnl.ac.id': 1,
#  'educationist.com.pk': 1,
#  'footpedals.net': 1,
#  'ftp.tuxmachines.org': 1,
#  'gerbilwithajetpack.com': 1,
#  'golftravelandleisure.com': 1,
#  'guriatourism.ge': 1,
#  'humdani.com': 1,
#  'ifelicious.com': 1,
#  'imdbfilm.top': 1,
#  'ishare.rediff.com': 1,
#  'javsubbed.net': 1,
#  'luckyethel.ethelbert.club': 1,
#  'mac-cracksoft.com': 1,
#  'mason.ss10.sharpschool.com': 1,
#  'memories.nebraska.gov': 1,
#  'michaelkusugak.editmy.website': 1,
#  'milliondollarburan.dx.am': 1,
#  'missbooklover.blogspot.com': 1,
#  'music.zortam.com': 1,
#  'neustemgen.nauka.szczecin.pl': 1,
#  'office365answers.com': 1,
#  'omnianews.com': 1,
#  'pages.sachachua.com': 1,
#  'paulgibsonmusic.com': 1,
#  'premiumpass.info': 1,
#  'pueyandtheprincess.conlang.org': 1,
#  'readsbookonline.com': 1,
#  'riebhopal.org': 1,
#  'ruggtuhor.webcindario.com': 1,
#  'rvfz.com': 1,
#  'shopping.rediff.com': 1,
#  'skinnyjeanschailatte.com': 1,
#  'stateofthenation.co': 1,
#  'stevestenzel.blogspot.com': 1,
#  'suimazate1989.no.comunidades.net': 1,
#  'terete.rammconference.org': 1,
#  'testsite.citygoddess.co.uk': 1,
#  'theliftiereport.rentskis.com': 1,
#  'todaycut.com': 1,
#  'urbanlatino.com': 1,
#  'vuaq.com': 1,
#  'whatislyme.com': 1,
#  'wrongsideoftheart.com': 1,
#  'www.alexcummingmusic.com': 1,
#  'www.all-fame.com': 1,
#  'www.barryschwartz.org': 1,
#  'www.blacktennispros.com': 1,
#  'www.buffalony.gov': 1,
#  'www.camtocamsexlive.com': 1,
#  'www.china-cart.com': 1,
#  'www.cityofknoxville.org': 1,
#  'www.cmt.com': 1,
#  'www.content-technology.com': 1,
#  'www.coolstreaming.us': 1,
#  'www.dontreadthelatin.com': 1,
#  'www.free-management-ebooks.com': 1,
#  'www.gamefuzz.com': 1,
#  'www.garyschwartzarthistorian.nl': 1,
#  'www.greenland-ar.com': 1,
#  'www.issuesmagazine.com.au': 1,
#  'www.itsmydarlin.com': 1,
#  'www.jackstracksmusic.com': 1,
#  'www.krapsody.com': 1,
#  'www.merritt.ca': 1,
#  'www.missteenagecanada.com': 1,
#  'www.motortestmagazine.com': 1,
#  'www.mountainmancomics.com': 1,
#  'www.mtv.co.uk': 1,
#  'www.mtv.com': 1,
#  'www.myadorablesmalltownlife.com': 1,
#  'www.oilpulling.com': 1,
#  'www.optionswealthmachinereview.com': 1,
#  'www.picslyrics.net': 1,
#  'www.slowlyboiledfrog.com': 1,
#  'www.somanyrecordssolittletime.com': 1,
#  'www.soundimage.eu': 1,
#  'www.sternenvironmental.com': 1,
#  'www.takingpaws.com': 1,
#  'www.trifivechevys.com': 1,
#  'www.tv.com': 1,
#  'www.unlikely-story.com': 1,
#  'www.valleyne.org': 1,
#  'www.wholesalesportsjerseysauthentic.com': 1,
#  'www.wingman.com.au': 1,
#  'xapkdown.com': 1,
#  '1061evansville.com': 1,
#  '3axis.co': 1,
#  'acedessays.com': 1,
#  'acetrade.ru': 1,
#  'africasacountry.com': 1,
#  'afrobeat.co.za': 1,
#  'alojav.com': 1,
#  'alt.cc': 1,
#  'altayer-travel.com': 1,
#  'andrea-gomoll.de': 1,
#  'angelamshupe.wordpress.com': 1,
#  'apkmr.com': 1,
#  'appdb.winehq.org': 1,
#  'autozu.ru': 1,
#  'backontherock.com': 1,
#  'baldonnel.prn.bc.ca': 1,
#  'barbtaub.com': 1,
#  'barkingsidelocksmiths.co.uk': 1,
#  'beautys-seduction.com': 1,
#  'bebehblog.com': 1,
#  'bekaboy.com': 1,
#  'best-of-hr.com': 1,
#  'bibliobeth.com': 1,
#  'billingadventure.com': 1,
#  'black.womensjacket.org': 1,
#  'blog.2createawebsite.com': 1,
#  'blog.hiddenharmonies.org': 1,
#  'blog.warwick.com.au': 1,
#  'boohardy.com': 1,
#  'bookreviewsbyshalini.com': 1,
#  'bramcotetoday.org.uk': 1,
#  'buypermanentmakeup.com': 1,
#  'c-movies.cc': 1,
#  'campuschildcare-old.wm.edu': 1,
#  'careers.nuca.com': 1,
#  'casetext.com': 1,
#  'cdn.shadesoflight.com': 1,
#  'celebrityinsider.org': 1,
#  'champaignil.gov': 1,
#  'chaturbate.monster': 1,
#  'cheatss.org': 1,
#  'cliqqs.com': 1,
#  'cloudtweaks.com': 1,
#  'consultingbyrpm.com': 1,
#  'coupleseekingwoman.net': 1,
#  'crackedprogramsfull.com': 1,
#  'daftsex.me': 1,
#  'darkgaytube.com': 1,
#  'deadline.com': 1,
#  'derobertiscaffe.com': 1,
#  'discountstaging.com': 1,
#  'diva.sfsu.edu': 1,
#  'dolanlawfirm.com': 1,
#  'donkeytime.org': 1,
#  'druyoga.com': 1,
#  'dryicons.com': 1,
#  'e-discoveryteam.com': 1,
#  'edtechdigest.com': 1,
#  'empireinv.com': 1,
#  'en.israelidiamond.co.il': 1,
#  'english.worldmagazine.it': 1,
#  'erccog.org': 1,
#  'erickimphotography.com': 1,
#  'erineph.com': 1,
#  'eryncarter.com': 1,
#  'eurovisionireland.net': 1,
#  'everything-kitchen.com.au': 1,
#  'faithhogan.com': 1,
#  'falcon.myvideostore.com': 1,
#  'fasab.wordpress.com': 1,
#  'fbfl.us': 1,
#  'fitnessista.com': 1,
#  'flagofulysses.com': 1,
#  'flawsomejem.com': 1,
#  'fmovies.town': 1,
#  'forestriverpartsdirect.com': 1,
#  'form.jotform.com': 1,
#  'forum.bodyjewelleryshop.com': 1,
#  'forum.charltonlife.com': 1,
#  'forum.flightgear.org': 1,
#  'forum.youngblacksf.com': 1,
#  'forums.moneysavingexpert.com': 1,
#  'forums.thesmartmarks.com': 1,
#  'forums.untangle.com': 1,
#  'frcontent.com': 1,
#  'futuristrendcast.wordpress.com': 1,
#  'gametrex.com': 1,
#  'ganjaland.store': 1,
#  'gb3artsdp.com': 1,
#  'gohardindaapaint.com': 1,
#  'gpad.ee': 1,
#  'grantschwartz.com': 1,
#  'greenenergyzim.misa.org': 1,
#  'growingforsuccess.com': 1,
#  'guardian.ng': 1,
#  'hamodia.com': 1,
#  'healthmanagement.org': 1,
#  'heiressllc.com': 1,
#  'hellomay.com.au': 1,
#  'hoaxteadresearch.wordpress.com': 1,
#  'homeopathybooks.in': 1,
#  'hondaownersmanualbooks.com': 1,
#  'houseintegrals.com': 1,
#  'idolforums.com': 1,
#  'iexplore.herokuapp.com': 1,
#  'iforinspirationblog.wordpress.com': 1,
#  'imageric.com': 1,
#  'independentpoliticalreport.com': 1,
#  'indianatalks.com': 1,
#  'indianidol.info': 1,
#  'ir.uwf.edu': 1,
#  'itauditsecurity.wordpress.com': 1,
#  'itvnetworks.tv': 1,
#  'jobs.designengine.com': 1,
#  'kalajaduvashikaranspecialist.com': 1,
#  'kennywiley.com': 1,
#  'kulinarie.ru': 1,
#  'kwikmedrillekes.nl': 1,
#  'larryatkersonministries.org': 1,
#  'laughingsquid.com': 1,
#  'lecturenotes.in': 1,
#  'lenoirbazaar.com': 1,
#  'library.maitland.nsw.gov.au': 1,
#  'licensedfull.com': 1,
#  'lolwallpapers.net': 1,
#  'lyndamullalyhunt.wordpress.com': 1,
#  'madeira-sa.co.za': 1,
#  'magazine.fresnostate.edu': 1,
#  'mc2ca.co.nz': 1,
#  'meandrichard.wordpress.com': 1,
#  'michaelfairmantv.com': 1,
#  'mods-ats.ru': 1,
#  'moviegalleri.net': 1,
#  'movies123.sh': 1,
#  'mp3djmix.com': 1,
#  'mpblogs.com': 1,
#  'ms01001041.schoolwires.net': 1,
#  'musicandlifeblog.com': 1,
#  'my.spokanecity.org': 1,
#  'nakedsecurity.sophos.com': 1,
#  'news.illinois.edu': 1,
#  'nextprojection.com': 1,
#  'nwn.blogs.com': 1,
#  'okejoss.co': 1,
#  'onefinebaby.com.au': 1,
#  'parisgolo.com': 1,
#  'pbgallery.polibolly.in': 1,
#  'petticoatsandpistols.com': 1,
#  'piedmontneighborhood.com': 1,
#  'pokemonromhack.com': 1,
#  'portable4pc.com': 1,
#  'prague.tv': 1,
#  'pulsenewsmexico.com': 1,
#  'qna.themarriagebed.com': 1,
#  'realitydaydream.com': 1,
#  'realtimeimages.photoshelter.com': 1,
#  'rnzaoc.com': 1,
#  'rspca-llysnini.org.uk': 1,
#  'russia1123.site': 1,
#  's36.a2zinc.net': 1,
#  'schinzelenterprise.com': 1,
#  'scifi.stackexchange.com': 1,
#  'search.audioburst.com': 1,
#  'secretartexpedition.wordpress.com': 1,
#  'serialswooper.com': 1,
#  'sheslayspodcast.com': 1,
#  'shivanshienterprise.co.in': 1,
#  'shop.afc.co.uk': 1,
#  'shop.atenasciandplay.com': 1,
#  'shop.fashionrooftop.com': 1,
#  'shop.gustoclothing.com': 1,
#  'sidepodcast.com': 1,
#  'sixpegs.com': 1,
#  'slavtelecom.ru': 1,
#  'sophiamoneycoutts.com': 1,
#  'soundbetter.com': 1,
#  'soundstudiesblog.com': 1,
#  'spacemov.vip': 1,
#  'sportswithneil.com': 1,
#  'standupgirl.com': 1,
#  'starcentralmagazine.com': 1,
#  'supportaustralia.wordpress.com': 1,
#  'tbcsupply.com': 1,
#  'teachoftime.com': 1,
#  'techurdu.net': 1,
#  'tesiklipsch.com': 1,
#  'thebikeaffair.com': 1,
#  'thedailyrecord.com': 1,
#  'thedepressedmoose.com': 1,
#  'thefrugalcrafter.wordpress.com': 1,
#  'theleftahead.com': 1,
#  'thelegwear.co': 1,
#  'themerkle.com': 1,
#  'thepeakfm.com': 1,
#  'therapyfriends.co.uk': 1,
#  'therdistrict.com': 1,
#  'therelationaleconomy.com': 1,
#  'thestandard.org.nz': 1,
#  'thewigstation.com': 1,
#  'theworldnewsdaily.com': 1,
#  'timesofindia.indiatimes.com': 1,
#  'tktrojanathletics.org': 1,
#  'trishop.tri-alliance.com': 1,
#  'truthsaves.org': 1,
#  'tutore.org': 1,
#  'u3astowmarket.wordpress.com': 1,
#  'utopia2nola.com': 1,
#  'vavana.co': 1,
#  'wardiary.wikileaks.org': 1,
#  'wavyhaircut.com': 1,
#  'wildfoodgirl.com': 1,
#  'ww1.icvalledeilaghi.it': 1,
#  'www-tracey.archive.org': 1,
#  'www.028zzz.com': 1,
#  'www.advanceduninstaller.com': 1,
#  'www.advantagegold.com': 1,
#  'www.alltechcorner.com': 1,
#  'www.alufabinc.com': 1,
#  'www.aoim.com': 1,
#  'www.artsper.com': 1,
#  'www.awakeningtoremembering.com': 1,
#  'www.axialentertainment.com': 1,
#  'www.backwardglances.com': 1,
#  'www.bar-weinig.nl': 1,
#  'www.barcelona-metropolitan.com': 1,
#  'www.bcu.ac.uk': 1,
#  'www.bestsoftware4download.com': 1,
#  'www.bikefriday.com': 1,
#  'www.biotherm.ca': 1,
#  'www.bolleblu.info': 1,
#  'www.bonosbible.com': 1,
#  'www.borrowmoney.com': 1,
#  'www.bowlingalmeria.com': 1,
#  'www.bradfordcityfc.co.uk': 1,
#  'www.bravohairy.com': 1,
#  'www.burnaby.ca': 1,
#  'www.candidjoyphotography.com': 1,
#  'www.canstockphoto.com': 1,
#  'www.cdc.gov': 1,
#  'www.chicagotribune.com': 1,
#  'www.cicklive.com': 1,
#  'www.cinechat.co.uk': 1,
#  'www.clintonsretail.com': 1,
#  'www.clipartguide.com': 1,
#  'www.concatenations.org': 1,
#  'www.cotswoldoutdoor.com': 1,
#  'www.crackedactivator.com': 1,
#  'www.dalgarnoinstitute.org.au': 1,
#  'www.danielgreenfield.org': 1,
#  'www.detroitgirlsdoitbetter.com': 1,
#  'www.dhgate.com': 1,
#  'www.docmh.com': 1,
#  'www.doublegames.com': 1,
#  'www.downsjuniormusic.com': 1,
#  'www.drive-download.com': 1,
#  'www.durham.ca': 1,
#  'www.edealinfo.com': 1,
#  'www.epa.wa.gov.au': 1,
#  'www.ericdress.com': 1,
#  'www.escortwww.com': 1,
#  'www.essence.com': 1,
#  'www.etsy.com': 1,
#  'www.exportersindia.com': 1,
#  'www.extra-urbano.com': 1,
#  'www.faithfamilybillings.com': 1,
#  'www.farshidmoussavi.com': 1,
#  'www.festivalclaca.cat': 1,
#  'www.fite.tv': 1,
#  'www.flamingo-fashion.co.uk': 1,
#  'www.footwearetc.com': 1,
#  'www.foreclosure.com': 1,
#  'www.freedownload.club': 1,
#  'www.freshnessmag.com': 1,
#  'www.futurelearn.com': 1,
#  'www.gaybuzzer.com': 1,
#  'www.gettyimages.co.nz': 1,
#  'www.gillinghamfootballclub.com': 1,
#  'www.gladwellacademy.com': 1,
#  'www.gpisd.org': 1,
#  'www.gracequeens.com': 1,
#  'www.greenportfashion.in': 1,
#  'www.groceryshopforfree.com': 1,
#  'www.growerssupply.com': 1,
#  'www.hayesswc.com': 1,
#  'www.idc.com': 1,
#  'www.ineffableisland.com': 1,
#  'www.inspiria.biz': 1,
#  'www.iwmbuzz.com': 1,
#  'www.jimheffernan.org': 1,
#  'www.josephlento.com': 1,
#  'www.joshklapow.com': 1,
#  'www.keithmurrayguitar.com': 1,
#  'www.khanbooks.net': 1,
#  'www.kirstyjarvie.com': 1,
#  'www.knfilters.com': 1,
#  'www.lallychev.com': 1,
#  'www.lawcentralalberta.ca': 1,
#  'www.letmegomovie.com': 1,
#  'www.levyjewelers.com': 1,
#  'www.lifeatcobblehillfarm.com': 1,
#  'www.lillianvernon.com': 1,
#  'www.local10.com': 1,
#  'www.lonny.com': 1,
#  'www.lurv.com.au': 1,
#  'www.marieclaire.com': 1,
#  'www.marion.sa.gov.au': 1,
#  'www.markjasonlacson.com': 1,
#  'www.math.wisc.edu': 1,
#  'www.memeorandum.com': 1,
#  'www.metrocleancarolinas.com': 1,
#  'www.micmurdbeatz.com': 1,
#  'www.mirror.co.uk': 1,
#  'www.momondo.co.uk': 1,
#  'www.musicradar.com': 1,
#  'www.mychamplainvalley.com': 1,
#  'www.mygamer.com': 1,
#  'www.myrelaxplace.com': 1,
#  'www.newscientist.com': 1,
#  'www.noctemaudio.com': 1,
#  'www.numberskill.com': 1,
#  'www.nzonscreen.com': 1,
#  'www.onlinepornotub.com': 1,
#  'www.onlinewebfonts.com': 1,
#  'www.ownerdirect.com': 1,
#  'www.papermag.com': 1,
#  'www.personalgrowth.com': 1,
#  'www.perth.wa.gov.au': 1,
#  'www.pixcove.com': 1,
#  'www.playmaths.co.za': 1,
#  'www.poppers-order.com': 1,
#  'www.powershow.com': 1,
#  'www.press-citizen.com': 1,
#  'www.prettyinthecity.ca': 1,
#  'www.rockcellarmagazine.com': 1,
#  'www.saddleback.edu': 1,
#  'www.salinashsbaseball.com': 1,
#  'www.savvymom.ca': 1,
#  'www.scarborounited.org': 1,
#  'www.sermonaudio.com': 1,
#  'www.sheetmusicplus.com': 1,
#  'www.shop4musicboxes.co.uk': 1,
#  'www.siemplify.co': 1,
#  'www.simply-start.com': 1,
#  'www.siouxfallsopen.com': 1,
#  'www.sorryimissedyourparty.com': 1,
#  'www.sothebys.com': 1,
#  'www.soundboard.com': 1,
#  'www.statusfacebook.com': 1,
#  'www.stayathomemum.com.au': 1,
#  'www.studentfy.com': 1,
#  'www.studydrive.net': 1,
#  'www.supplyroom.com': 1,
#  'www.swadesimaal.com': 1,
#  'www.theava.com': 1,
#  'www.thebrenkusteam.com': 1,
#  'www.thecut.com': 1,
#  'www.theedgemarkets.com': 1,
#  'www.thefamilytravelblog.com': 1,
#  'www.themoscowtimes.com': 1,
#  'www.themurrayhometeam.com': 1,
#  'www.theperfectbath.com': 1,
#  'www.therailroadcollection.com': 1,
#  'www.thesouthafrican.com': 1,
#  'www.thinkinghumanity.com': 1,
#  'www.tightstightstights.co.uk': 1,
#  'www.topeka.org': 1,
#  'www.torontoenvironment.org': 1,
#  'www.totalsportek.com': 1,
#  'www.townplanner.com': 1,
#  'www.tucsonaz.gov': 1,
#  'www.tuffshop.co.uk': 1,
#  'www.turlockcitynews.com': 1,
#  'www.tvnewsroom.org': 1,
#  'www.tzima.com': 1,
#  'www.umista.ca': 1,
#  'www.unexplained-mysteries.com': 1,
#  'www.urbal-integration.eu': 1,
#  'www.vacanzecolcuore.com': 1,
#  'www.valdezak.gov': 1,
#  'www.viewbug.com': 1,
#  'www.visitpenticton.com': 1,
#  'www.vnhax.net': 1,
#  'www.vpshoes.com': 1,
#  'www.watereducation.org': 1,
#  'www.weasyl.com': 1,
#  'www.wgt.com': 1,
#  'www.wideopencountry.com': 1,
#  'www.wiedamark.com': 1,
#  'www.wikihow.com': 1,
#  'www.wildwestbootstore.com': 1,
#  'www.windows7download.com': 1,
#  'www.withinnigeria.com': 1,
#  'www.womensactivewear.com': 1,
#  'www.woofandme.co.uk': 1,
#  'www.wvc.edu': 1,
#  'www.xupes.com': 1,
#  'www.yes2yoga.net': 1,
#  'www.yeswellness.com': 1,
#  'wz010.nl': 1,
#  'yashry.com': 1,
#  'yourhealthcoachbiz.com': 1,
#  'yourhealthradio.org': 1,
#  'yourlifeasartessentials.com': 1,
#  '0x0133c6f0becfbb55306c4549a162eb15e42ab69d.0xeth.com': 0,
#  '101things.com': 0,
#  '1024x.net': 0,
#  '156street-lausd-ca.schoolloop.com': 0,
#  '1920vidcofurnitoph.gazepti0fairnish.us.org': 0,
#  '199099.gov.sa:89': 0,
#  '1mt.top': 0,
#  '2012.igem.org': 0,
#  '2012.northernspark.org': 0,
#  '24hourcredit.info': 0,
#  '24ktgoldpoker.com': 0,
#  '32ndstreet-uscmagnet.schoolloop.com': 0,
#  '3dvideosystems.com': 0,
#  '3g.tbh16rg.cn': 0,
#  '3tfederal.com': 0,
#  '4b.wusdjqt.cn': 0,
#  '4g.haoyun205.cn': 0,
#  '5001.ws': 0,
#  '5amjoel.com': 0,
#  '9fishgames.com': 0,
#  'aa.trinimuslims.com': 0,
#  'aaisp-btmso.blogspot.com': 0,
#  'abandoned-images.com': 0,
#  'ac-fix.com': 0,
#  'acornfc.co.uk': 0,
#  'acqtrain.com': 0,
#  'activecheshire.org': 0,
#  'adassacouture.tripod.com': 0,
#  'adhunt.blogspot.com': 0,
#  'adkrispies.blogspot.com': 0,
#  'adlinewrites.blogspot.com': 0,
#  'adrenalyn.net': 0,
#  'adressbuecher.net': 0,
#  'ads4world.com': 0,
#  'aerosociety.cirqahosting.com': 0,
#  'afa.at': 0,
#  'africana.fiu.edu': 0,
#  'africanelements.com': 0,
#  'ageod-forum.com': 0,
#  'ahfr.dit.ie': 0,
#  'akasha.mynetav.com': 0,
#  'akzlaw.com': 0,
#  'al.is.tuebingen.mpg.de': 0,
#  'alat.sith.itb.ac.id': 0,
#  'aleofatime.com': 0,
#  'alexwritesstuff.com': 0,
#  'alienplantsbelgium.be': 0,
#  'alipic.net': 0,
#  'alleygirl.com': 0,
#  'allornothingtattoo.com': 0,
#  'allthingskaty.blogspot.com': 0,
#  'allyouneedisbass.com': 0,
#  'amazingspidermancgc.name': 0,
#  'amiright.com': 0,
#  'amp.indiarailinfo.com': 0,
#  'ampminsure.org': 0,
#  'amsmu.b0tnet.com': 0,
#  'amusebouche.nl': 0,
#  'amusement.itsgames.com': 0,
#  'anamcara-press.com': 0,
#  'anatasolutions.com': 0,
#  'andrestudios.nypl.org': 0,
#  'angryrabbitstudios.com': 0,
#  'annanews.com': 0,
#  'annklein.northhillsrealty.com': 0,
#  'anntweedale.org': 0,
#  'anothernightelf.blogspot.com': 0,
#  'antikva.blogspot.com': 0,
#  'antropovskayask.ucoz.ru': 0,
#  'aon.iab.uaf.edu': 0,
#  'apopoflife.com': 0,
#  'appalachianaristocracy.com': 0,
#  'apppm.man.dtu.dk': 0,
#  'apps.cccski.com': 0,
#  'aqmx.lymphedemapeople.com': 0,
#  'aquila.bio.nyu.edu': 0,
#  'archeagedatabase.net': 0,
#  'archive.forum.travian.co.uk': 0,
#  'archive.nflgridirongab.com': 0,
#  'archive.nyafuu.org': 0,
#  'archive.wn.com': 0,
#  'archive.zbrushcentral.com': 0,
#  'archives.karnataka.gov.in': 0,
#  'archives.mees.com': 0,
#  'archivesearch.library.nuigalway.ie': 0,
#  'arewehuman.iksv.org': 0,
#  'arizonaescrowcompany.com': 0,
#  'aroundthevalleyin60days.blogspot.com': 0,
#  'arrow.latrobe.edu.au:8080': 0,
#  'artandarchitecture.org.uk': 0,
#  'articleguestposting.com': 0,
#  'ashleyludwig.com': 0,
#  'askrebecca.guru': 0,
#  'assessment.engin.umich.edu': 0,
#  'assignments.uspto.gov': 0,
#  'at-chloro.prabi.fr': 0,
#  'atcinsulators.com': 0,
#  'attackpoint.org': 0,
#  'aulas.fcq.unc.edu.ar': 0,
#  'austinfoodmagazine.com': 0,
#  'autokutnohorska.cz': 0,
#  'autos.pennlive.com': 0,
#  'autumfame.net': 0,
#  'avalon.tsukaeru.jp': 0,
#  'awe.mudcat.org': 0,
#  'axis.apache.org': 0,
#  'axiv.cmsilsole.it': 0,
#  'azureclean.com': 0,
#  'b3.zcubes.com': 0,
#  'baask.com': 0,
#  'backupyoursaves.blogspot.com': 0,
#  'baggiesbackpackers.com': 0,
#  'baltimoretimes-online.com': 0,
#  'banda.csp-sofia.org': 0,
#  'bapd.org': 0,
#  'barrandov.crestyl.com': 0,
#  'basketball.exchange.ph': 0,
#  'basketballtrainingaid.com': 0,
#  'batterie.mashslotsmash.xyz': 0,
#  'battlehelm.com': 0,
#  'bayonheritage.com': 0,
#  'bbq-brethren.com': 0,
#  'bbs.cyberjamz.com': 0,
#  'bearssportsandoutdoors.com': 0,
#  'beatsandrhymesradio.exclaim.ca': 0,
#  'bedrockroanoke.com': 0,
#  'belfastsciencefiction.org.uk': 0,
#  'belovedkeepsakes.blogspot.com': 0,
#  'benzackheim.com': 0,
#  'bettywrightjones.com': 0,
#  'bevbusson.sencanada.ca': 0,
#  'bikemoviemusic.com': 0,
#  'billhillmusic.net': 0,
#  'biochar.bioenergylists.org': 0,
#  'bioeconomy.eu': 0,
#  'biostall.com': 0,
#  'bir.brandeis.edu': 0,
#  'bjlincoln.blogspot.com': 0,
#  'blankcastshow.blubrry.com': 0,
#  'blog.100am.co': 0,
#  'blog.airindiaexpress.in': 0,
#  'blog.blackmael.com': 0,
#  'blog.calcoastwebdesign.com': 0,
#  'blog.charet.com': 0,
#  'blog.crapandcrapability.com': 0,
#  'blog.edlisten.com': 0,
#  'blog.electromotion.co.uk': 0,
#  'blog.islandchildbirth.com': 0,
#  'blog.junbelen.com': 0,
#  'blog.michelelauriat.com': 0,
#  'blog.monophotos.org': 0,
#  'blog.nekodojo.org': 0,
#  'blog.princeofdiamonds.org': 0,
#  'blog.shinadachi.com': 0,
#  'blog.stanlophotography.com': 0,
#  'blog.stewart.com': 0,
#  'blog.tadhack.com': 0,
#  'blog.tolovearose.com': 0,
#  'blog.triptribe.com': 0,
#  'blog.yf2pdqj.cn': 0,
#  'blogodise.blogspot.com': 0,
#  'blogs.avalonconsult.com': 0,
#  'blogs.bath.ac.uk': 0,
#  'blogs.edweek.org': 0,
#  'blogs.mycentraljersey.com': 0,
#  'bloodletting.org': 0,
#  'board.shearwatermusic.com': 0,
#  'board.themat.com': 0,
#  'boardgamelifestyle.com': 0,
#  'boards.rebkell.net': 0,
#  'boatbanter.co.uk': 0,
#  'bolp.org': 0,
#  'boojum.scripts.mit.edu': 0,
#  'book.caltech.edu': 0,
#  'book.wherethewildriverruns.com': 0,
#  'booking.visithelgeland.com': 0,
#  'bookstore.potsdam.edu': 0,
#  'bookwi.se': 0,
#  'bounty.indreams-studios.com': 0,
#  'boxerkennelvarsenerhof.nl': 0,
#  'bq.sg': 0,
#  'bramhambenefice.org': 0,
#  'brandonbrownattorneychicago.com': 0,
#  'brantly.info': 0,
#  'briarpress.org': 0,
#  'bristolmumfestival.org': 0,
#  'britisharabnetwork.co.uk': 0,
#  'britishnotes.co.uk': 0,
#  'brokenarrowarchery.com': 0,
#  'brookfieldschools.org': 0,
#  'brooklynheightsblog.com': 0,
#  'btownerrant.com': 0,
#  'bugs.navsplace.net': 0,
#  'builtbyjay.com': 0,
#  'business-degree.fun': 0,
#  'business.albanyga.com': 0,
#  'business.bigbearchamber.com': 0,
#  'businessofgovernment.org': 0,
#  'buyersguide.physicstoday.org': 0,
#  'buyersguide.spine.org': 0,
#  'c4owners.org': 0,
#  'ca.worldpronews.com': 0,
#  'caitlintrussell.org': 0,
#  'calendar.ircgov.com': 0,
#  'calendar.rendcombcollege.org.uk': 0,
#  'calguns.net': 0,
#  'calvarycouponers.com': 0,
#  'canadacashmoney.com': 0,
#  'canadianlotterypools.com': 0,
#  'captaincomics.ning.com': 0,
#  'carbono.utpl.edu.ec:8080': 0,
#  'careers.kent.co.in': 0,
#  'careers.konekt.com.au': 0,
#  'caribfreelance.com': 0,
#  'carlylemedicalcentre.co.nz': 0,
#  'carmenho.com': 0,
#  'carwreckers.co.nz': 0,
#  'catalog.library.washco.utah.gov': 0,
#  'catherinegowthorpe.com': 0,
#  'cbankruptcy.atigraphics.com': 0,
#  'cdn.attracta.com': 0,
#  'cdn.mailboxmap.com': 0,
#  'cdn.picmonkey.com': 0,
#  'cdn.tradingeconomics.com': 0,
#  'cee.umass.edu': 0,
#  'celebnreality247.com': 0,
#  'ceness-russia.org': 0,
#  'cercetari-arheologice.ro': 0,
#  'cerco.cs.unibo.it': 0,
#  'cfd.nu.edu.pk': 0,
#  ...}

# %%
len({k: v for k, v in pornsites.items() if v > 3})
# Out:
# 167

# %%
167.00/12903.00
# Out:
# 0.01294272649771371
